# %% [markdown]
# # EECS 498-007/598-005 Assignment 3-1: Fully-Connected Neural Networks and Dropout
#
# Before we start, please put your name and UMID in following format
#
# : Firstname LASTNAME, #00000000   //   e.g.) Justin JOHNSON, #12345678

# %% [markdown]
# **Your Answer:**
# Your NAME, #XXXXXXXX

# %% [markdown]
# ## Setup Code
# Before getting started, we need to run some boilerplate code to set up our environment, same as Assignment 1. You'll need to rerun this setup code each time you start the notebook.
#
# First, run this cell load the autoreload extension. This allows us to edit .py source files, and re-import them into the notebook for a seamless editing and debugging experience.

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Google Colab Setup
# Next we need to run a few commands to set up our environment on Google Colab. If you are running this notebook on a local machine you can skip this section.
#
# Run the following cell to mount your Google Drive. Follow the link, sign in to your Google account (the same account you used to store this notebook!) and copy the authorization code into the text box that appears below.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# Now recall the path in your Google Drive where you uploaded this notebook, fill it in below. If everything is working correctly then running the folowing cell should print the filenames from the assignment:
#
# ```
# ['convolutional_networks.ipynb', 'fully_connected_networks.ipynb', 'eecs598', 'convolutional_networks.py', 'fully_connected_networks.py', 'a3_helper.py']
# ```

# %%
import os

# TODO: Fill in the Google Drive path where you uploaded the assignment
# Example: If you create a 2022WI folder and put all the files under A3 folder, then '2022WI/A3'
GOOGLE_DRIVE_PATH_AFTER_MYDRIVE = None
GOOGLE_DRIVE_PATH = os.path.join('drive', 'My Drive', GOOGLE_DRIVE_PATH_AFTER_MYDRIVE)
print(os.listdir(GOOGLE_DRIVE_PATH))

# %% [markdown]
# Once you have successfully mounted your Google Drive and located the path to this assignment, run th following cell to allow us to import from the `.py` files of this assignment. If it works correctly, it should print the message:
#
# ```
# Hello from fully_connected_networks.py!
# Hello from a3_helper.py!
# ```
#
# as well as the last edit time for the file `fully_connected_networks.py`.

# %%
import sys
sys.path.append(GOOGLE_DRIVE_PATH)

import time, os
os.environ["TZ"] = "US/Eastern"
time.tzset()

from fully_connected_networks import hello_fully_connected_networks
hello_fully_connected_networks()

from a3_helper import hello_helper
hello_helper()

fully_connected_networks_path = os.path.join(GOOGLE_DRIVE_PATH, 'fully_connected_networks.py')
fully_connected_networks_edit_time = time.ctime(os.path.getmtime(fully_connected_networks_path))
print('fully_connected_networks.py last edited on %s' % fully_connected_networks_edit_time)

# %% [markdown]
# # Data preprocessing

# %% [markdown]
# ## Setup code
# Run some setup code for this notebook: Import some useful packages and increase the default figure size.

# %%
import eecs598
import torch
import torchvision
import matplotlib.pyplot as plt
import statistics
import random
import time
import math
# %matplotlib inline

from eecs598 import reset_seed, Solver

plt.rcParams['figure.figsize'] = (10.0, 8.0)
plt.rcParams['font.size'] = 16

# %% [markdown]
# Starting in this assignment, we will use the GPU to accelerate our computation. Run this cell to make sure you are using a GPU.

# %%
if torch.cuda.is_available:
  print('Good to go!')
else:
  print('Please set GPU via Edit -> Notebook Settings.')
# Out:
# Good to go!

# %% [markdown]
# ## Load the CIFAR-10 dataset
# Then, we will first load the CIFAR-10 dataset. The utility function `eecs598.data.preprocess_cifar10()` returns the entire CIFAR-10 dataset as a set of six **Torch tensors** while also preprocessing the RGB images:
#
# - `X_train` contains all training images (real numbers in the range $[0, 1]$)
# - `y_train` contains all training labels (integers in the range $[0, 9]$)
# - `X_val` contains all validation images
# - `y_val` contains all validation labels
# - `X_test` contains all test images
# - `y_test` contains all test labels

# %%
# Invoke the above function to get our data. 
import eecs598

eecs598.reset_seed(0)
data_dict = eecs598.data.preprocess_cifar10(cuda=True, dtype=torch.float64)
print('Train data shape: ', data_dict['X_train'].shape)
print('Train labels shape: ', data_dict['y_train'].shape)
print('Validation data shape: ', data_dict['X_val'].shape)
print('Validation labels shape: ', data_dict['y_val'].shape)
print('Test data shape: ', data_dict['X_test'].shape)
print('Test labels shape: ', data_dict['y_test'].shape)
# Out:
# Train data shape:  torch.Size([40000, 3072])
# Train labels shape:  torch.Size([40000])
# Validation data shape:  torch.Size([10000, 3072])
# Validation labels shape:  torch.Size([10000])
# Test data shape:  torch.Size([10000, 3072])
# Test labels shape:  torch.Size([10000])

# %% [markdown]
# # Fully-connected neural networks
# In the previous homework you implemented a fully-connected two-layer neural network on CIFAR-10. The implementation was simple but not very modular since the loss and gradient were computed in a single monolithic function. This is manageable for a simple two-layer network, but would become impractical as we move to bigger models. Ideally we want to build networks using a more modular design so that we can implement different layer types in isolation and then snap them together into models with different architectures.

# %% [markdown]
# In this exercise we will implement fully-connected networks using a more modular approach. For each layer we will implement a `forward` and a `backward` function. The `forward` function will receive inputs, weights, and other parameters and will return both an output and a `cache` object storing data needed for the backward pass, like this:
#
# ```python
# def forward(x, w):
#   """ Receive inputs x and weights w """
#   # Do some computations ...
#   z = # ... some intermediate value
#   # Do some more computations ...
#   out = # the output
#
#   cache = (x, w, z, out) # Values we need to compute gradients
#
#   return out, cache
# ```
#
# The backward pass will receive upstream derivatives and the `cache` object, and will return gradients with respect to the inputs and weights, like this:
#
# ```python
# def backward(dout, cache):
#   """
#   Receive dout (derivative of loss with respect to outputs) and cache,
#   and compute derivative with respect to inputs.
#   """
#   # Unpack cache values
#   x, w, z, out = cache
#
#   # Use values in cache to compute derivatives
#   dx = # Derivative of loss with respect to x
#   dw = # Derivative of loss with respect to w
#
#   return dx, dw
# ```
#
# After implementing a bunch of layers this way, we will be able to easily combine them to build classifiers with different architectures.
#
# In addition to implementing fully-connected networks of arbitrary depth, we will also explore different update rules for optimization, and introduce Dropout as a regularizer as a tool to more efficiently optimize deep networks.
#
# To validate our implementation, we will compare the analytically computed gradients with numerical approximations of the gradient as done in previous assignments. You can inspect the numeric gradient function `compute_numeric_gradient` in `eecs598/grad.py`. Please note that we have updated the function to accept upstream gradients to allow us to debug intermediate layers easily. You can check the update description by running the code block below.

# %%
help(eecs598.grad.compute_numeric_gradient)
# Out:
# Help on function compute_numeric_gradient in module eecs598.grad:
#
# compute_numeric_gradient(f, x, dLdf=None, h=1e-07)
#     Compute the numeric gradient of f at x using a finite differences
#     approximation. We use the centered difference:
#
#     df    f(x + h) - f(x - h)
#     -- ~= -------------------
#     dx           2 * h
#
#     Function can also expand this easily to intermediate layers using the
#     chain rule:
#
#     dL   df   dL
#     -- = -- * --
#     dx   dx   df
#
#     Inputs:
#     - f: A function that inputs a torch tensor and returns a torch scalar
#     - x: A torch tensor giving the point at which to compute the gradient
#     - dLdf: optional upstream gradient for intermediate layers
#     - h: epsilon used in the finite difference calculation
#     Returns:
#     - grad: A tensor of the same shape as x giving the gradient of f at x

# %% [markdown]
# # Linear layer

# %% [markdown]
# For each layer we implement, we will define a class with two static methods `forward` and `backward`. The class structure is currently provided in `fully_connected_layers.py`, you will be implementing both the `forward` and `backward` methods.

# %% [markdown]
# ## Linear layer: forward
# Implement the `Linear.forward` function in `fully_connected_layers.py`. Once you are done you can test your implementaion by running the next cell. You should see errors less than `1e-7`.

# %%
from fully_connected_networks import Linear

# Test the Linear.forward function
num_inputs = 2
input_shape = torch.tensor((4, 5, 6))
output_dim = 3

input_size = num_inputs * torch.prod(input_shape)
weight_size = output_dim * torch.prod(input_shape)

x = torch.linspace(-0.1, 0.5, steps=input_size, dtype=torch.float64, device='cuda')
w = torch.linspace(-0.2, 0.3, steps=weight_size, dtype=torch.float64, device='cuda')
b = torch.linspace(-0.3, 0.1, steps=output_dim, dtype=torch.float64, device='cuda')
x = x.reshape(num_inputs, *input_shape)
w = w.reshape(torch.prod(input_shape), output_dim)

out, _ = Linear.forward(x, w, b)
correct_out = torch.tensor([[1.49834984, 1.70660150, 1.91485316],
                            [3.25553226, 3.51413301, 3.77273372]]
                            ).double().cuda()

print('Testing Linear.forward function:')
print('difference: ', eecs598.grad.rel_error(out, correct_out))
# Out:
# Testing Linear.forward function:
# difference:  3.683042917976506e-08

# %% [markdown]
# ## Linear layer: backward
# Now implement the `Linear.backward` function and test your implementation using numeric gradient checking.
#
# Run the following to test your implementation of `Linear.backward`. You should see errors less than `1e-7`.

# %%
from fully_connected_networks import Linear

# Test the Linear.backward function
reset_seed(0)
x = torch.randn(10, 2, 3, dtype=torch.float64, device='cuda')
w = torch.randn(6, 5, dtype=torch.float64, device='cuda')
b = torch.randn(5, dtype=torch.float64, device='cuda')
dout = torch.randn(10, 5, dtype=torch.float64, device='cuda')

dx_num = eecs598.grad.compute_numeric_gradient(lambda x: Linear.forward(x, w, b)[0], x, dout)
dw_num = eecs598.grad.compute_numeric_gradient(lambda w: Linear.forward(x, w, b)[0], w, dout)
db_num = eecs598.grad.compute_numeric_gradient(lambda b: Linear.forward(x, w, b)[0], b, dout)

_, cache = Linear.forward(x, w, b)
dx, dw, db = Linear.backward(dout, cache)
print(dx_num.shape)
# The error should be around e-10 or less
print('Testing Linear.backward function:')
print('dx error: ', eecs598.grad.rel_error(dx_num, dx))
print('dw error: ', eecs598.grad.rel_error(dw_num, dw))
print('db error: ', eecs598.grad.rel_error(db_num, db))
# Out:
# torch.Size([10, 2, 3])
# Testing Linear.backward function:
# dx error:  5.540736853994794e-10
# dw error:  3.964520455338778e-10
# db error:  5.373171200544344e-10

# %% [markdown]
# # ReLU activation

# %% [markdown]
# We will now implement the ReLU nonlinearity. As above, we will define a class with two empty static methods, and implement them in upcoming cells. The class structure can be found in `fully_connected_networks.py`

# %% [markdown]
# ## ReLU activation: forward
# Implement the forward pass for the ReLU activation function in the `ReLU.forward` function. You **should not** change the input tensor with an in-place operation.
#
# Run the following to test your implementation of the ReLU forward pass. Your errors should be less than `1e-7`.

# %%
from fully_connected_networks import ReLU

reset_seed(0)
x = torch.linspace(-0.5, 0.5, steps=12, dtype=torch.float64, device='cuda')
x = x.reshape(3, 4)

out, _ = ReLU.forward(x)
correct_out = torch.tensor([[ 0.,          0.,          0.,          0.,        ],
                            [ 0.,          0.,          0.04545455,  0.13636364,],
                            [ 0.22727273,  0.31818182,  0.40909091,  0.5,       ]],
                            dtype=torch.float64,
                            device='cuda')

# Compare your output with ours. The error should be on the order of e-8
print('Testing ReLU.forward function:')
print(out.shape)
print(correct_out.shape)
print('difference: ', eecs598.grad.rel_error(out, correct_out))
# Out:
# Testing ReLU.forward function:
# torch.Size([3, 4])
# torch.Size([3, 4])
# difference:  4.5454545613554664e-09

# %% [markdown]
# ## ReLU activation: backward
# Now implement the backward pass for the ReLU activation function.
#
# Again, you should not change the input tensor with an in-place operation.
#
# Run the following to test your implementation of `ReLU.backward`. Your errors should be less than `1e-8`.

# %%
from fully_connected_networks import ReLU

reset_seed(0)
x = torch.randn(10, 10, dtype=torch.float64, device='cuda')
dout = torch.randn(*x.shape, dtype=torch.float64, device='cuda')

dx_num = eecs598.grad.compute_numeric_gradient(lambda x: ReLU.forward(x)[0], x, dout)

_, cache = ReLU.forward(x)
dx = ReLU.backward(dout, cache)

# The error should be on the order of e-12
print('Testing ReLU.backward function:')
print('dx error: ', eecs598.grad.rel_error(dx_num, dx))
# Out:
# Testing ReLU.backward function:
# dx error:  2.6317796097761553e-10

# %% [markdown]
# # "Sandwich" layers
# There are some common patterns of layers that are frequently used in neural nets. For example, linear layers are frequently followed by a ReLU nonlinearity. To make these common patterns easy, we define a convenience layer.
#
# This also shows how our layer abstraction allows us to implement new layers by composing existing layer implementations. This is a powerful mechanism for structuring deep learning code in a modular fashion.
#
# For now take a look at the `forward` and `backward` functions in `Linear_ReLU`, and run the following to numerically gradient check the backward pass.
#
# Run the following to test the implementation of the `Linear_ReLU` layer using numeric gradient checking. You should see errors less than `1e-8`

# %%
from fully_connected_networks import Linear_ReLU

reset_seed(0)
x = torch.randn(2, 3, 4, dtype=torch.float64, device='cuda')
w = torch.randn(12, 10, dtype=torch.float64, device='cuda')
b = torch.randn(10, dtype=torch.float64, device='cuda')
dout = torch.randn(2, 10, dtype=torch.float64, device='cuda')

out, cache = Linear_ReLU.forward(x, w, b)
dx, dw, db = Linear_ReLU.backward(dout, cache)

dx_num = eecs598.grad.compute_numeric_gradient(lambda x: Linear_ReLU.forward(x, w, b)[0], x, dout)
dw_num = eecs598.grad.compute_numeric_gradient(lambda w: Linear_ReLU.forward(x, w, b)[0], w, dout)
db_num = eecs598.grad.compute_numeric_gradient(lambda b: Linear_ReLU.forward(x, w, b)[0], b, dout)

# Relative error should be around e-8 or less
print('Testing Linear_ReLU.forward and Linear_ReLU.backward:')
print('dx error: ', eecs598.grad.rel_error(dx_num, dx))
print('dw error: ', eecs598.grad.rel_error(dw_num, dw))
print('db error: ', eecs598.grad.rel_error(db_num, db))
# Out:
# Testing Linear_ReLU.forward and Linear_ReLU.backward:
# dx error:  1.210759699545244e-09
# dw error:  7.462948482161807e-10
# db error:  8.915028842081707e-10

# %% [markdown]
# # Loss layers: Softmax and SVM
# You implemented these loss functions in the last assignment, so we'll give them to you for free in `helper_functions.py`. You should still make sure you understand how they work by looking at the implementations. We can first verify our implementations.
#
#
# Run the following to perform numeric gradient checking on the two loss functions. You should see errors less than `1e-7` for svm_loss and `1e-6` for softmax_loss.

# %%
from a3_helper import svm_loss, softmax_loss

reset_seed(0)
num_classes, num_inputs = 10, 50
x = 0.001 * torch.randn(num_inputs, num_classes, dtype=torch.float64, device='cuda')
y = torch.randint(num_classes, size=(num_inputs,), dtype=torch.int64, device='cuda')

dx_num = eecs598.grad.compute_numeric_gradient(lambda x: svm_loss(x, y)[0], x)
loss, dx = svm_loss(x, y)

# Test svm_loss function. Loss should be around 9 and dx error should be around the order of e-9
print('Testing svm_loss:')
print('loss: ', loss.item())
print('dx error: ', eecs598.grad.rel_error(dx_num, dx))

dx_num = eecs598.grad.compute_numeric_gradient(lambda x: softmax_loss(x, y)[0], x)
loss, dx = softmax_loss(x, y)

# Test softmax_loss function. Loss should be close to 2.3 and dx error should be around e-8
print('\nTesting softmax_loss:')
print('loss: ', loss.item())
print('dx error: ', eecs598.grad.rel_error(dx_num, dx))
# Out:
# Testing svm_loss:
# loss:  9.000430792478463
# dx error:  2.0074935157654598e-08
#
# Testing softmax_loss:
# loss:  2.3026286102347924
# dx error:  1.0417990899757076e-07

# %% [markdown]
# # Two-layer network
# In the previous assignment you implemented a two-layer neural network in a single monolithic class. Now that you have implemented modular versions of the necessary layers, you will reimplement the two layer network using these modular implementations.
#
# Complete the implementation of the `TwoLayerNet` class. This class will serve as a model for the other networks you will implement in this assignment, so read through it to make sure you understand the API.
#
# Once you have finished implementing the forward and backward passes of your two-layer net, run the following to test your implementation:

# %%
from fully_connected_networks import TwoLayerNet
from a3_helper import svm_loss, softmax_loss

reset_seed(0)
N, D, H, C = 3, 5, 50, 7
X = torch.randn(N, D, dtype=torch.float64, device='cuda')
y = torch.randint(C, size=(N,), dtype=torch.int64, device='cuda')

std = 1e-3
model = TwoLayerNet(
          input_dim=D,
          hidden_dim=H,
          num_classes=C,
          weight_scale=std,
          dtype=torch.float64,
          device='cuda'
        )

print('Testing initialization ... ')
W1_std = torch.abs(model.params['W1'].std() - std)
b1 = model.params['b1']
W2_std = torch.abs(model.params['W2'].std() - std)
b2 = model.params['b2']
assert W1_std < std / 10, 'First layer weights do not seem right'
assert torch.all(b1 == 0), 'First layer biases do not seem right'
assert W2_std < std / 10, 'Second layer weights do not seem right'
assert torch.all(b2 == 0), 'Second layer biases do not seem right'

print('Testing test-time forward pass ... ')
model.params['W1'] = torch.linspace(-0.7, 0.3, steps=D * H, dtype=torch.float64, device='cuda').reshape(D, H)
model.params['b1'] = torch.linspace(-0.1, 0.9, steps=H, dtype=torch.float64, device='cuda')
model.params['W2'] = torch.linspace(-0.3, 0.4, steps=H * C, dtype=torch.float64, device='cuda').reshape(H, C)
model.params['b2'] = torch.linspace(-0.9, 0.1, steps=C, dtype=torch.float64, device='cuda')
X = torch.linspace(-5.5, 4.5, steps=N * D, dtype=torch.float64, device='cuda').reshape(D, N).t()
scores = model.loss(X)
correct_scores = torch.tensor(
  [[11.53165108,  12.2917344,   13.05181771,  13.81190102,  14.57198434, 15.33206765,  16.09215096],
   [12.05769098,  12.74614105,  13.43459113,  14.1230412,   14.81149128, 15.49994135,  16.18839143],
   [12.58373087,  13.20054771,  13.81736455,  14.43418138,  15.05099822, 15.66781506,  16.2846319 ]],
    dtype=torch.float64, device='cuda')
scores_diff = torch.abs(scores - correct_scores).sum()
assert scores_diff < 1e-6, 'Problem with test-time forward pass'

print('Testing training loss (no regularization)')
y = torch.tensor([0, 5, 1])
loss, grads = model.loss(X, y)
correct_loss = 3.4702243556
assert abs(loss - correct_loss) < 1e-10, 'Problem with training-time loss'

model.reg = 1.0
loss, grads = model.loss(X, y)
correct_loss = 49.719461034881775
assert abs(loss - correct_loss) < 1e-10, 'Problem with regularization loss'

# Errors should be around e-6 or less
for reg in [0.0, 0.7]:
  print('Running numeric gradient check with reg = ', reg)
  model.reg = reg
  loss, grads = model.loss(X, y)

  for name in sorted(grads):
    f = lambda _: model.loss(X, y)[0]
    grad_num = eecs598.grad.compute_numeric_gradient(f, model.params[name])
    print('%s relative error: %.2e' % (name, eecs598.grad.rel_error(grad_num, grads[name])))
# Out:
# Testing initialization ...
# Testing test-time forward pass ...
# Testing training loss (no regularization)
# Running numeric gradient check with reg =  0.0
# W1 relative error: 2.94e-07
# W2 relative error: 1.65e-09
# b1 relative error: 1.01e-06
# b2 relative error: 4.63e-09
# Running numeric gradient check with reg =  0.7
# W1 relative error: 2.70e-08
# W2 relative error: 9.86e-09
# b1 relative error: 2.28e-06
# b2 relative error: 2.90e-08

# %% [markdown]
# # Solver
# In the previous assignment, the logic for training models was coupled to the models themselves. Following a more modular design, for this assignment we have split the logic for training models into a separate class.
#
# Read through `help(Solver)` to familiarize yourself with the API. After doing so, use a `Solver` instance to train a `TwoLayerNet` that achieves at least `50%` accuracy on the validation set.

# %%
print(help(Solver))
# Out:
# Help on class Solver in module eecs598.solver:
#
# class Solver(builtins.object)
#  |  Solver(model, data, **kwargs)
#  |
#  |  A Solver encapsulates all the logic necessary for training classification
#  |  models. The Solver performs stochastic gradient descent using different
#  |  update rules.
#  |  The solver accepts both training and validation data and labels so it can
#  |  periodically check classification accuracy on both training and validation
#  |  data to watch out for overfitting.
#  |  To train a model, you will first construct a Solver instance, passing the
#  |  model, dataset, and various options (learning rate, batch size, etc) to the
#  |  constructor. You will then call the train() method to run the optimization
#  |  procedure and train the model.
#  |  After the train() method returns, model.params will contain the parameters
#  |  that performed best on the validation set over the course of training.
#  |  In addition, the instance variable solver.loss_history will contain a list
#  |  of all losses encountered during training and the instance variables
#  |  solver.train_acc_history and solver.val_acc_history will be lists of the
#  |  accuracies of the model on the training and validation set at each epoch.
#  |  Example usage might look something like this:
#  |  data = {
#  |    'X_train': # training data
#  |    'y_train': # training labels
#  |    'X_val': # validation data
#  |    'y_val': # validation labels
#  |  }
#  |  model = MyAwesomeModel(hidden_size=100, reg=10)
#  |  solver = Solver(model, data,
#  |          update_rule=sgd,
#  |          optim_config={
#  |            'learning_rate': 1e-3,
#  |          },
#  |          lr_decay=0.95,
#  |          num_epochs=10, batch_size=100,
#  |          print_every=100,
#  |          device='cuda')
#  |  solver.train()
#  |  A Solver works on a model object that must conform to the following API:
#  |  - model.params must be a dictionary mapping string parameter names to torch
#  |    tensors containing parameter values.
#  |  - model.loss(X, y) must be a function that computes training-time loss and
#  |    gradients, and test-time classification scores, with the following inputs
#  |    and outputs:
#  |    Inputs:
#  |    - X: Array giving a minibatch of input data of shape (N, d_1, ..., d_k)
#  |    - y: Array of labels, of shape (N,) giving labels for X where y[i] is the
#  |    label for X[i].
#  |    Returns:
#  |    If y is None, run a test-time forward pass and return:
#  |    - scores: Array of shape (N, C) giving classification scores for X where
#  |    scores[i, c] gives the score of class c for X[i].
#  |    If y is not None, run a training time forward and backward pass and
#  |    return a tuple of:
#  |    - loss: Scalar giving the loss
#  |    - grads: Dictionary with the same keys as self.params mapping parameter
#  |    names to gradients of the loss with respect to those parameters.
#  |    - device: device to use for computation. 'cpu' or 'cuda'
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, model, data, **kwargs)
#  |      Construct a new Solver instance.
#  |      Required arguments:
#  |      - model: A model object conforming to the API described above
#  |      - data: A dictionary of training and validation data containing:
#  |        'X_train': Array, shape (N_train, d_1, ..., d_k) of training images
#  |        'X_val': Array, shape (N_val, d_1, ..., d_k) of validation images
#  |        'y_train': Array, shape (N_train,) of labels for training images
#  |        'y_val': Array, shape (N_val,) of labels for validation images
#  |      Optional arguments:
#  |      - update_rule: A function of an update rule. Default is sgd.
#  |      - optim_config: A dictionary containing hyperparameters that will be
#  |        passed to the chosen update rule. Each update rule requires different
#  |        hyperparameters but all update rules require a
#  |        'learning_rate' parameter so that should always be present.
#  |      - lr_decay: A scalar for learning rate decay; after each epoch the
#  |        learning rate is multiplied by this value.
#  |      - batch_size: Size of minibatches used to compute loss and gradient
#  |        during training.
#  |      - num_epochs: The number of epochs to run for during training.
#  |      - print_every: Integer; training losses will be printed every
#  |        print_every iterations.
#  |      - print_acc_every: We will print the accuracy every
#  |        print_acc_every epochs.
#  |      - verbose: Boolean; if set to false then no output will be printed
#  |        during training.
#  |      - num_train_samples: Number of training samples used to check training
#  |        accuracy; default is 1000; set to None to use entire training set.
#  |      - num_val_samples: Number of validation samples to use to check val
#  |        accuracy; default is None, which uses the entire validation set.
#  |      - checkpoint_name: If not None, then save model checkpoints here every
#  |        epoch.
#  |
#  |  check_accuracy(self, X, y, num_samples=None, batch_size=100)
#  |      Check accuracy of the model on the provided data.
#  |      Inputs:
#  |      - X: Array of data, of shape (N, d_1, ..., d_k)
#  |      - y: Array of labels, of shape (N,)
#  |      - num_samples: If not None, subsample the data and only test the model
#  |        on num_samples datapoints.
#  |      - batch_size: Split X and y into batches of this size to avoid using
#  |        too much memory.
#  |      Returns:
#  |      - acc: Scalar giving the fraction of instances that were correctly
#  |        classified by the model.
#  |
#  |  train(self, time_limit=None, return_best_params=True)
#  |      Run optimization to train the model.
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  sgd(w, dw, config=None)
#  |      Performs vanilla stochastic gradient descent.
#  |      config format:
#  |      - learning_rate: Scalar learning rate.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#
# None

# %% [markdown]
# Use the Solver classe to create a solver instance that trains a TwoLayerNet to achieve at least 50% performance on the validation set.
#
# **Implement** `create_solver_instance` in `fully_connected_networks.py` to return a solver instance. Make sure to initialize the Solver instance with the input device.

# %%
from fully_connected_networks import create_solver_instance

reset_seed(0)

# Create a solver instance that achieves 50% performance on the validation set
solver = create_solver_instance(data_dict=data_dict, dtype=torch.float64, device='cuda')
solver.train()
# Out:
# (Time 0.66 sec; Iteration 1 / 40000) loss: 2.302585
# (Epoch 0 / 100) train acc: 0.123000; val_acc: 0.108400
# (Time 1.00 sec; Iteration 11 / 40000) loss: 2.302562
# (Time 1.08 sec; Iteration 21 / 40000) loss: 2.302519
# (Time 1.16 sec; Iteration 31 / 40000) loss: 2.302620
# (Time 1.24 sec; Iteration 41 / 40000) loss: 2.302471
# (Time 1.32 sec; Iteration 51 / 40000) loss: 2.302091
# (Time 1.40 sec; Iteration 61 / 40000) loss: 2.302740
# (Time 1.48 sec; Iteration 71 / 40000) loss: 2.302545
# (Time 1.55 sec; Iteration 81 / 40000) loss: 2.302142
# (Time 1.63 sec; Iteration 91 / 40000) loss: 2.302126
# (Time 1.71 sec; Iteration 101 / 40000) loss: 2.302436
# (Time 1.79 sec; Iteration 111 / 40000) loss: 2.302536
# (Time 1.88 sec; Iteration 121 / 40000) loss: 2.301932
# (Time 1.95 sec; Iteration 131 / 40000) loss: 2.302317
# (Time 2.03 sec; Iteration 141 / 40000) loss: 2.302490
# (Time 2.12 sec; Iteration 151 / 40000) loss: 2.301929
# (Time 2.20 sec; Iteration 161 / 40000) loss: 2.302431
# (Time 2.27 sec; Iteration 171 / 40000) loss: 2.302371
# (Time 2.35 sec; Iteration 181 / 40000) loss: 2.302094
# (Time 2.43 sec; Iteration 191 / 40000) loss: 2.302244
# (Time 2.50 sec; Iteration 201 / 40000) loss: 2.302220
# (Time 2.58 sec; Iteration 211 / 40000) loss: 2.301564
# (Time 2.66 sec; Iteration 221 / 40000) loss: 2.301794
# (Time 2.74 sec; Iteration 231 / 40000) loss: 2.302087
# (Time 2.81 sec; Iteration 241 / 40000) loss: 2.301571
# (Time 2.89 sec; Iteration 251 / 40000) loss: 2.301802
# (Time 2.97 sec; Iteration 261 / 40000) loss: 2.301413
# (Time 3.05 sec; Iteration 271 / 40000) loss: 2.300977
# (Time 3.12 sec; Iteration 281 / 40000) loss: 2.300593
# (Time 3.20 sec; Iteration 291 / 40000) loss: 2.301029
# (Time 3.28 sec; Iteration 301 / 40000) loss: 2.300526
# (Time 3.35 sec; Iteration 311 / 40000) loss: 2.300790
# (Time 3.43 sec; Iteration 321 / 40000) loss: 2.301683
# (Time 3.51 sec; Iteration 331 / 40000) loss: 2.301851
# (Time 3.59 sec; Iteration 341 / 40000) loss: 2.300679
# (Time 3.67 sec; Iteration 351 / 40000) loss: 2.299891
# (Time 3.75 sec; Iteration 361 / 40000) loss: 2.298842
# (Time 3.83 sec; Iteration 371 / 40000) loss: 2.300366
# (Time 3.91 sec; Iteration 381 / 40000) loss: 2.299377
# (Time 3.99 sec; Iteration 391 / 40000) loss: 2.299351
# (Epoch 1 / 100) train acc: 0.189000; val_acc: 0.178700
# (Time 4.33 sec; Iteration 401 / 40000) loss: 2.297828
# (Time 4.41 sec; Iteration 411 / 40000) loss: 2.297156
# (Time 4.49 sec; Iteration 421 / 40000) loss: 2.292414
# (Time 4.57 sec; Iteration 431 / 40000) loss: 2.295306
# (Time 4.64 sec; Iteration 441 / 40000) loss: 2.292720
# (Time 4.72 sec; Iteration 451 / 40000) loss: 2.292909
# (Time 4.79 sec; Iteration 461 / 40000) loss: 2.294338
# (Time 4.87 sec; Iteration 471 / 40000) loss: 2.286219
# (Time 4.94 sec; Iteration 481 / 40000) loss: 2.291635
# (Time 5.02 sec; Iteration 491 / 40000) loss: 2.297086
# (Time 5.10 sec; Iteration 501 / 40000) loss: 2.285777
# (Time 5.18 sec; Iteration 511 / 40000) loss: 2.284997
# (Time 5.26 sec; Iteration 521 / 40000) loss: 2.284705
# (Time 5.33 sec; Iteration 531 / 40000) loss: 2.279147
# (Time 5.41 sec; Iteration 541 / 40000) loss: 2.277139
# (Time 5.48 sec; Iteration 551 / 40000) loss: 2.267565
# (Time 5.56 sec; Iteration 561 / 40000) loss: 2.267446
# (Time 5.64 sec; Iteration 571 / 40000) loss: 2.265989
# (Time 5.72 sec; Iteration 581 / 40000) loss: 2.275346
# (Time 5.79 sec; Iteration 591 / 40000) loss: 2.268311
# (Time 5.87 sec; Iteration 601 / 40000) loss: 2.258592
# (Time 5.94 sec; Iteration 611 / 40000) loss: 2.252141
# (Time 6.02 sec; Iteration 621 / 40000) loss: 2.231216
# (Time 6.09 sec; Iteration 631 / 40000) loss: 2.262951
# (Time 6.17 sec; Iteration 641 / 40000) loss: 2.245221
# (Time 6.25 sec; Iteration 651 / 40000) loss: 2.238531
# (Time 6.32 sec; Iteration 661 / 40000) loss: 2.240118
# (Time 6.40 sec; Iteration 671 / 40000) loss: 2.261980
# (Time 6.47 sec; Iteration 681 / 40000) loss: 2.257161
# (Time 6.55 sec; Iteration 691 / 40000) loss: 2.246168
# (Time 6.62 sec; Iteration 701 / 40000) loss: 2.246834
# (Time 6.70 sec; Iteration 711 / 40000) loss: 2.224058
# (Time 6.77 sec; Iteration 721 / 40000) loss: 2.244645
# (Time 6.85 sec; Iteration 731 / 40000) loss: 2.162335
# (Time 6.93 sec; Iteration 741 / 40000) loss: 2.207537
# (Time 7.00 sec; Iteration 751 / 40000) loss: 2.153118
# (Time 7.08 sec; Iteration 761 / 40000) loss: 2.201673
# (Time 7.16 sec; Iteration 771 / 40000) loss: 2.186151
# (Time 7.23 sec; Iteration 781 / 40000) loss: 2.199103
# (Time 7.31 sec; Iteration 791 / 40000) loss: 2.224265
# (Epoch 2 / 100) train acc: 0.167000; val_acc: 0.178900
# (Time 7.65 sec; Iteration 801 / 40000) loss: 2.165281
# (Time 7.72 sec; Iteration 811 / 40000) loss: 2.183396
# (Time 7.80 sec; Iteration 821 / 40000) loss: 2.197681
# (Time 7.87 sec; Iteration 831 / 40000) loss: 2.173172
# (Time 7.95 sec; Iteration 841 / 40000) loss: 2.168392
# (Time 8.03 sec; Iteration 851 / 40000) loss: 2.197909
# (Time 8.10 sec; Iteration 861 / 40000) loss: 2.131462
# (Time 8.18 sec; Iteration 871 / 40000) loss: 2.169098
# (Time 8.25 sec; Iteration 881 / 40000) loss: 2.191341
# (Time 8.33 sec; Iteration 891 / 40000) loss: 2.257591
# (Time 8.41 sec; Iteration 901 / 40000) loss: 2.192225
# (Time 8.48 sec; Iteration 911 / 40000) loss: 2.190085
# (Time 8.56 sec; Iteration 921 / 40000) loss: 2.155297
# (Time 8.63 sec; Iteration 931 / 40000) loss: 2.170769
# (Time 8.72 sec; Iteration 941 / 40000) loss: 2.133410
# (Time 8.80 sec; Iteration 951 / 40000) loss: 2.123829
# (Time 8.87 sec; Iteration 961 / 40000) loss: 2.155493
# (Time 8.95 sec; Iteration 971 / 40000) loss: 2.149668
# (Time 9.02 sec; Iteration 981 / 40000) loss: 2.152226
# (Time 9.10 sec; Iteration 991 / 40000) loss: 2.152789
# (Time 9.18 sec; Iteration 1001 / 40000) loss: 2.107270
# (Time 9.25 sec; Iteration 1011 / 40000) loss: 2.196030
# (Time 9.33 sec; Iteration 1021 / 40000) loss: 2.171918
# (Time 9.40 sec; Iteration 1031 / 40000) loss: 2.135784
# (Time 9.48 sec; Iteration 1041 / 40000) loss: 2.076485
# (Time 9.56 sec; Iteration 1051 / 40000) loss: 2.112721
# (Time 9.63 sec; Iteration 1061 / 40000) loss: 2.077284
# (Time 9.71 sec; Iteration 1071 / 40000) loss: 2.131939
# (Time 9.78 sec; Iteration 1081 / 40000) loss: 2.084592
# (Time 9.86 sec; Iteration 1091 / 40000) loss: 2.062672
# (Time 9.94 sec; Iteration 1101 / 40000) loss: 2.082759
# (Time 10.01 sec; Iteration 1111 / 40000) loss: 2.077361
# (Time 10.09 sec; Iteration 1121 / 40000) loss: 2.086912
# (Time 10.17 sec; Iteration 1131 / 40000) loss: 2.072383
# (Time 10.25 sec; Iteration 1141 / 40000) loss: 2.095365
# (Time 10.32 sec; Iteration 1151 / 40000) loss: 2.086540
# (Time 10.40 sec; Iteration 1161 / 40000) loss: 2.176241
# (Time 10.47 sec; Iteration 1171 / 40000) loss: 2.063064
# (Time 10.55 sec; Iteration 1181 / 40000) loss: 2.076200
# (Time 10.63 sec; Iteration 1191 / 40000) loss: 2.075274
# (Epoch 3 / 100) train acc: 0.255000; val_acc: 0.237300
# (Time 10.97 sec; Iteration 1201 / 40000) loss: 2.048962
# (Time 11.04 sec; Iteration 1211 / 40000) loss: 2.084871
# (Time 11.12 sec; Iteration 1221 / 40000) loss: 2.087104
# (Time 11.19 sec; Iteration 1231 / 40000) loss: 2.143928
# (Time 11.27 sec; Iteration 1241 / 40000) loss: 2.099136
# (Time 11.35 sec; Iteration 1251 / 40000) loss: 2.182573
# (Time 11.42 sec; Iteration 1261 / 40000) loss: 2.105068
# (Time 11.50 sec; Iteration 1271 / 40000) loss: 2.125098
# (Time 11.58 sec; Iteration 1281 / 40000) loss: 2.058310
# (Time 11.65 sec; Iteration 1291 / 40000) loss: 1.985936
# (Time 11.73 sec; Iteration 1301 / 40000) loss: 2.112493
# (Time 11.82 sec; Iteration 1311 / 40000) loss: 2.128418
# (Time 11.89 sec; Iteration 1321 / 40000) loss: 2.099556
# (Time 11.97 sec; Iteration 1331 / 40000) loss: 1.993776
# (Time 12.04 sec; Iteration 1341 / 40000) loss: 2.047521
# (Time 12.12 sec; Iteration 1351 / 40000) loss: 2.093898
# (Time 12.21 sec; Iteration 1361 / 40000) loss: 2.091708
# (Time 12.28 sec; Iteration 1371 / 40000) loss: 2.098788
# (Time 12.36 sec; Iteration 1381 / 40000) loss: 1.991238
# (Time 12.44 sec; Iteration 1391 / 40000) loss: 2.108075
# (Time 12.52 sec; Iteration 1401 / 40000) loss: 2.110144
# (Time 12.59 sec; Iteration 1411 / 40000) loss: 1.968796
# (Time 12.67 sec; Iteration 1421 / 40000) loss: 2.020355
# (Time 12.75 sec; Iteration 1431 / 40000) loss: 2.004541
# (Time 12.82 sec; Iteration 1441 / 40000) loss: 2.105436
# (Time 12.90 sec; Iteration 1451 / 40000) loss: 2.063797
# (Time 12.97 sec; Iteration 1461 / 40000) loss: 2.020243
# (Time 13.05 sec; Iteration 1471 / 40000) loss: 2.048761
# (Time 13.13 sec; Iteration 1481 / 40000) loss: 1.956973
# (Time 13.20 sec; Iteration 1491 / 40000) loss: 2.106107
# (Time 13.28 sec; Iteration 1501 / 40000) loss: 1.980091
# (Time 13.36 sec; Iteration 1511 / 40000) loss: 1.996779
# (Time 13.43 sec; Iteration 1521 / 40000) loss: 2.003025
# (Time 13.51 sec; Iteration 1531 / 40000) loss: 2.043458
# (Time 13.58 sec; Iteration 1541 / 40000) loss: 2.120874
# (Time 13.66 sec; Iteration 1551 / 40000) loss: 2.045837
# (Time 13.74 sec; Iteration 1561 / 40000) loss: 1.998781
# (Time 13.81 sec; Iteration 1571 / 40000) loss: 1.887197
# (Time 13.89 sec; Iteration 1581 / 40000) loss: 1.937738
# (Time 13.96 sec; Iteration 1591 / 40000) loss: 1.987321
# (Epoch 4 / 100) train acc: 0.234000; val_acc: 0.254800
# (Time 14.30 sec; Iteration 1601 / 40000) loss: 2.088173
# (Time 14.38 sec; Iteration 1611 / 40000) loss: 2.003766
# (Time 14.45 sec; Iteration 1621 / 40000) loss: 2.008908
# (Time 14.53 sec; Iteration 1631 / 40000) loss: 2.051781
# (Time 14.61 sec; Iteration 1641 / 40000) loss: 2.033987
# (Time 14.68 sec; Iteration 1651 / 40000) loss: 1.947298
# (Time 14.76 sec; Iteration 1661 / 40000) loss: 2.043932
# (Time 14.84 sec; Iteration 1671 / 40000) loss: 2.050788
# (Time 14.91 sec; Iteration 1681 / 40000) loss: 2.054940
# (Time 14.99 sec; Iteration 1691 / 40000) loss: 1.936587
# (Time 15.07 sec; Iteration 1701 / 40000) loss: 1.924611
# (Time 15.15 sec; Iteration 1711 / 40000) loss: 1.956056
# (Time 15.22 sec; Iteration 1721 / 40000) loss: 1.981327
# (Time 15.30 sec; Iteration 1731 / 40000) loss: 2.041066
# (Time 15.38 sec; Iteration 1741 / 40000) loss: 1.975000
# (Time 15.45 sec; Iteration 1751 / 40000) loss: 1.971059
# (Time 15.53 sec; Iteration 1761 / 40000) loss: 2.008622
# (Time 15.61 sec; Iteration 1771 / 40000) loss: 2.029753
# (Time 15.68 sec; Iteration 1781 / 40000) loss: 1.948574
# (Time 15.76 sec; Iteration 1791 / 40000) loss: 2.014191
# (Time 15.84 sec; Iteration 1801 / 40000) loss: 1.952299
# (Time 15.91 sec; Iteration 1811 / 40000) loss: 1.861642
# (Time 15.99 sec; Iteration 1821 / 40000) loss: 2.105984
# (Time 16.06 sec; Iteration 1831 / 40000) loss: 1.993685
# (Time 16.14 sec; Iteration 1841 / 40000) loss: 1.957668
# (Time 16.22 sec; Iteration 1851 / 40000) loss: 1.995191
# (Time 16.29 sec; Iteration 1861 / 40000) loss: 1.946071
# (Time 16.37 sec; Iteration 1871 / 40000) loss: 2.015769
# (Time 16.44 sec; Iteration 1881 / 40000) loss: 1.949739
# (Time 16.52 sec; Iteration 1891 / 40000) loss: 2.136955
# (Time 16.60 sec; Iteration 1901 / 40000) loss: 1.978132
# (Time 16.67 sec; Iteration 1911 / 40000) loss: 1.824099
# (Time 16.75 sec; Iteration 1921 / 40000) loss: 1.886588
# (Time 16.83 sec; Iteration 1931 / 40000) loss: 1.957192
# (Time 16.90 sec; Iteration 1941 / 40000) loss: 1.991179
# (Time 16.97 sec; Iteration 1951 / 40000) loss: 1.987823
# (Time 17.05 sec; Iteration 1961 / 40000) loss: 2.010129
# (Time 17.13 sec; Iteration 1971 / 40000) loss: 1.930845
# (Time 17.20 sec; Iteration 1981 / 40000) loss: 1.850070
# (Time 17.28 sec; Iteration 1991 / 40000) loss: 2.007116
# (Epoch 5 / 100) train acc: 0.287000; val_acc: 0.283200
# (Time 17.61 sec; Iteration 2001 / 40000) loss: 1.977283
# (Time 17.69 sec; Iteration 2011 / 40000) loss: 2.015050
# (Time 17.76 sec; Iteration 2021 / 40000) loss: 1.905490
# (Time 17.84 sec; Iteration 2031 / 40000) loss: 1.931976
# (Time 17.92 sec; Iteration 2041 / 40000) loss: 1.950988
# (Time 17.99 sec; Iteration 2051 / 40000) loss: 1.982927
# (Time 18.07 sec; Iteration 2061 / 40000) loss: 1.966565
# (Time 18.14 sec; Iteration 2071 / 40000) loss: 1.874649
# (Time 18.22 sec; Iteration 2081 / 40000) loss: 1.963737
# (Time 18.29 sec; Iteration 2091 / 40000) loss: 1.913871
# (Time 18.37 sec; Iteration 2101 / 40000) loss: 1.857850
# (Time 18.45 sec; Iteration 2111 / 40000) loss: 1.985766
# (Time 18.52 sec; Iteration 2121 / 40000) loss: 1.972195
# (Time 18.60 sec; Iteration 2131 / 40000) loss: 1.989179
# (Time 18.68 sec; Iteration 2141 / 40000) loss: 2.006193
# (Time 18.75 sec; Iteration 2151 / 40000) loss: 2.014084
# (Time 18.83 sec; Iteration 2161 / 40000) loss: 1.897649
# (Time 18.90 sec; Iteration 2171 / 40000) loss: 1.840006
# (Time 18.98 sec; Iteration 2181 / 40000) loss: 1.992107
# (Time 19.05 sec; Iteration 2191 / 40000) loss: 1.861913
# (Time 19.13 sec; Iteration 2201 / 40000) loss: 1.951436
# (Time 19.20 sec; Iteration 2211 / 40000) loss: 1.972376
# (Time 19.28 sec; Iteration 2221 / 40000) loss: 1.978964
# (Time 19.35 sec; Iteration 2231 / 40000) loss: 1.888669
# (Time 19.43 sec; Iteration 2241 / 40000) loss: 1.870604
# (Time 19.51 sec; Iteration 2251 / 40000) loss: 1.851691
# (Time 19.59 sec; Iteration 2261 / 40000) loss: 1.983440
# (Time 19.67 sec; Iteration 2271 / 40000) loss: 1.976292
# (Time 19.74 sec; Iteration 2281 / 40000) loss: 1.957741
# (Time 19.82 sec; Iteration 2291 / 40000) loss: 1.817674
# (Time 19.90 sec; Iteration 2301 / 40000) loss: 2.012500
# (Time 19.99 sec; Iteration 2311 / 40000) loss: 1.917237
# (Time 20.08 sec; Iteration 2321 / 40000) loss: 1.919502
# (Time 20.16 sec; Iteration 2331 / 40000) loss: 1.956404
# (Time 20.23 sec; Iteration 2341 / 40000) loss: 1.869851
# (Time 20.31 sec; Iteration 2351 / 40000) loss: 1.819270
# (Time 20.38 sec; Iteration 2361 / 40000) loss: 1.841016
# (Time 20.46 sec; Iteration 2371 / 40000) loss: 1.817394
# (Time 20.54 sec; Iteration 2381 / 40000) loss: 2.030938
# (Time 20.62 sec; Iteration 2391 / 40000) loss: 1.881412
# (Epoch 6 / 100) train acc: 0.318000; val_acc: 0.307600
# (Time 20.95 sec; Iteration 2401 / 40000) loss: 1.986584
# (Time 21.03 sec; Iteration 2411 / 40000) loss: 1.977470
# (Time 21.10 sec; Iteration 2421 / 40000) loss: 1.962505
# (Time 21.19 sec; Iteration 2431 / 40000) loss: 1.842693
# (Time 21.27 sec; Iteration 2441 / 40000) loss: 1.934385
# (Time 21.34 sec; Iteration 2451 / 40000) loss: 1.904460
# (Time 21.42 sec; Iteration 2461 / 40000) loss: 1.946793
# (Time 21.49 sec; Iteration 2471 / 40000) loss: 1.873489
# (Time 21.57 sec; Iteration 2481 / 40000) loss: 1.743572
# (Time 21.65 sec; Iteration 2491 / 40000) loss: 1.965931
# (Time 21.72 sec; Iteration 2501 / 40000) loss: 1.867366
# (Time 21.80 sec; Iteration 2511 / 40000) loss: 1.815162
# (Time 21.87 sec; Iteration 2521 / 40000) loss: 1.813070
# (Time 21.95 sec; Iteration 2531 / 40000) loss: 1.854911
# (Time 22.02 sec; Iteration 2541 / 40000) loss: 1.914442
# (Time 22.10 sec; Iteration 2551 / 40000) loss: 1.855530
# (Time 22.18 sec; Iteration 2561 / 40000) loss: 1.836016
# (Time 22.26 sec; Iteration 2571 / 40000) loss: 2.006743
# (Time 22.34 sec; Iteration 2581 / 40000) loss: 1.759472
# (Time 22.41 sec; Iteration 2591 / 40000) loss: 1.819660
# (Time 22.49 sec; Iteration 2601 / 40000) loss: 1.853805
# (Time 22.58 sec; Iteration 2611 / 40000) loss: 1.831052
# (Time 22.67 sec; Iteration 2621 / 40000) loss: 2.038953
# (Time 22.76 sec; Iteration 2631 / 40000) loss: 1.812300
# (Time 22.85 sec; Iteration 2641 / 40000) loss: 1.953993
# (Time 22.94 sec; Iteration 2651 / 40000) loss: 1.937903
# (Time 23.03 sec; Iteration 2661 / 40000) loss: 2.022964
# (Time 23.12 sec; Iteration 2671 / 40000) loss: 1.873860
# (Time 23.22 sec; Iteration 2681 / 40000) loss: 1.884624
# (Time 23.31 sec; Iteration 2691 / 40000) loss: 1.874572
# (Time 23.40 sec; Iteration 2701 / 40000) loss: 1.869688
# (Time 23.49 sec; Iteration 2711 / 40000) loss: 1.811877
# (Time 23.59 sec; Iteration 2721 / 40000) loss: 1.700045
# (Time 23.68 sec; Iteration 2731 / 40000) loss: 1.832878
# (Time 23.78 sec; Iteration 2741 / 40000) loss: 1.887391
# (Time 23.89 sec; Iteration 2751 / 40000) loss: 1.736766
# (Time 23.98 sec; Iteration 2761 / 40000) loss: 1.910576
# (Time 24.07 sec; Iteration 2771 / 40000) loss: 1.921729
# (Time 24.16 sec; Iteration 2781 / 40000) loss: 2.050030
# (Time 24.25 sec; Iteration 2791 / 40000) loss: 1.811790
# (Epoch 7 / 100) train acc: 0.330000; val_acc: 0.326800
# (Time 24.60 sec; Iteration 2801 / 40000) loss: 1.919460
# (Time 24.69 sec; Iteration 2811 / 40000) loss: 1.830034
# (Time 24.78 sec; Iteration 2821 / 40000) loss: 1.924968
# (Time 24.87 sec; Iteration 2831 / 40000) loss: 1.888791
# (Time 24.96 sec; Iteration 2841 / 40000) loss: 1.713788
# (Time 25.05 sec; Iteration 2851 / 40000) loss: 1.746730
# (Time 25.15 sec; Iteration 2861 / 40000) loss: 1.880654
# (Time 25.24 sec; Iteration 2871 / 40000) loss: 1.873025
# (Time 25.33 sec; Iteration 2881 / 40000) loss: 1.817934
# (Time 25.42 sec; Iteration 2891 / 40000) loss: 1.788092
# (Time 25.51 sec; Iteration 2901 / 40000) loss: 1.856347
# (Time 25.60 sec; Iteration 2911 / 40000) loss: 1.796083
# (Time 25.69 sec; Iteration 2921 / 40000) loss: 1.940555
# (Time 25.78 sec; Iteration 2931 / 40000) loss: 1.853528
# (Time 25.87 sec; Iteration 2941 / 40000) loss: 1.743652
# (Time 25.96 sec; Iteration 2951 / 40000) loss: 1.858803
# (Time 26.06 sec; Iteration 2961 / 40000) loss: 1.870597
# (Time 26.15 sec; Iteration 2971 / 40000) loss: 1.807375
# (Time 26.24 sec; Iteration 2981 / 40000) loss: 1.797270
# (Time 26.33 sec; Iteration 2991 / 40000) loss: 1.852548
# (Time 26.42 sec; Iteration 3001 / 40000) loss: 1.929643
# (Time 26.52 sec; Iteration 3011 / 40000) loss: 1.872036
# (Time 26.61 sec; Iteration 3021 / 40000) loss: 1.899322
# (Time 26.71 sec; Iteration 3031 / 40000) loss: 1.777242
# (Time 26.80 sec; Iteration 3041 / 40000) loss: 1.873558
# (Time 26.89 sec; Iteration 3051 / 40000) loss: 1.850401
# (Time 26.98 sec; Iteration 3061 / 40000) loss: 1.764423
# (Time 27.07 sec; Iteration 3071 / 40000) loss: 1.742547
# (Time 27.16 sec; Iteration 3081 / 40000) loss: 1.710664
# (Time 27.25 sec; Iteration 3091 / 40000) loss: 1.866516
# (Time 27.35 sec; Iteration 3101 / 40000) loss: 1.747080
# (Time 27.43 sec; Iteration 3111 / 40000) loss: 1.960618
# (Time 27.52 sec; Iteration 3121 / 40000) loss: 1.663088
# (Time 27.62 sec; Iteration 3131 / 40000) loss: 1.855923
# (Time 27.71 sec; Iteration 3141 / 40000) loss: 1.765031
# (Time 27.80 sec; Iteration 3151 / 40000) loss: 1.891223
# (Time 27.89 sec; Iteration 3161 / 40000) loss: 1.769742
# (Time 27.98 sec; Iteration 3171 / 40000) loss: 1.735604
# (Time 28.07 sec; Iteration 3181 / 40000) loss: 1.778247
# (Time 28.17 sec; Iteration 3191 / 40000) loss: 1.760258
# (Epoch 8 / 100) train acc: 0.363000; val_acc: 0.342400
# (Time 28.53 sec; Iteration 3201 / 40000) loss: 1.753378
# (Time 28.63 sec; Iteration 3211 / 40000) loss: 1.866775
# (Time 28.72 sec; Iteration 3221 / 40000) loss: 1.728089
# (Time 28.81 sec; Iteration 3231 / 40000) loss: 1.806869
# (Time 28.89 sec; Iteration 3241 / 40000) loss: 1.772409
# (Time 28.98 sec; Iteration 3251 / 40000) loss: 1.811223
# (Time 29.08 sec; Iteration 3261 / 40000) loss: 1.806144
# (Time 29.18 sec; Iteration 3271 / 40000) loss: 1.698125
# (Time 29.26 sec; Iteration 3281 / 40000) loss: 1.815631
# (Time 29.36 sec; Iteration 3291 / 40000) loss: 1.898806
# (Time 29.45 sec; Iteration 3301 / 40000) loss: 1.813267
# (Time 29.54 sec; Iteration 3311 / 40000) loss: 1.859184
# (Time 29.63 sec; Iteration 3321 / 40000) loss: 1.804864
# (Time 29.72 sec; Iteration 3331 / 40000) loss: 1.849372
# (Time 29.81 sec; Iteration 3341 / 40000) loss: 1.731069
# (Time 29.91 sec; Iteration 3351 / 40000) loss: 1.719632
# (Time 30.00 sec; Iteration 3361 / 40000) loss: 1.830549
# (Time 30.09 sec; Iteration 3371 / 40000) loss: 1.731186
# (Time 30.18 sec; Iteration 3381 / 40000) loss: 1.700295
# (Time 30.27 sec; Iteration 3391 / 40000) loss: 1.873486
# (Time 30.36 sec; Iteration 3401 / 40000) loss: 1.881913
# (Time 30.46 sec; Iteration 3411 / 40000) loss: 1.724947
# (Time 30.55 sec; Iteration 3421 / 40000) loss: 1.783171
# (Time 30.64 sec; Iteration 3431 / 40000) loss: 1.756910
# (Time 30.74 sec; Iteration 3441 / 40000) loss: 1.915142
# (Time 30.83 sec; Iteration 3451 / 40000) loss: 1.795096
# (Time 30.92 sec; Iteration 3461 / 40000) loss: 1.991335
# (Time 31.01 sec; Iteration 3471 / 40000) loss: 1.836272
# (Time 31.10 sec; Iteration 3481 / 40000) loss: 1.776186
# (Time 31.19 sec; Iteration 3491 / 40000) loss: 1.789580
# (Time 31.28 sec; Iteration 3501 / 40000) loss: 1.683403
# (Time 31.37 sec; Iteration 3511 / 40000) loss: 1.699587
# (Time 31.47 sec; Iteration 3521 / 40000) loss: 1.849469
# (Time 31.56 sec; Iteration 3531 / 40000) loss: 1.762234
# (Time 31.65 sec; Iteration 3541 / 40000) loss: 1.917293
# (Time 31.74 sec; Iteration 3551 / 40000) loss: 1.747541
# (Time 31.83 sec; Iteration 3561 / 40000) loss: 1.751643
# (Time 31.92 sec; Iteration 3571 / 40000) loss: 1.780948
# (Time 32.02 sec; Iteration 3581 / 40000) loss: 1.845885
# (Time 32.11 sec; Iteration 3591 / 40000) loss: 1.858675
# (Epoch 9 / 100) train acc: 0.361000; val_acc: 0.356200
# (Time 32.47 sec; Iteration 3601 / 40000) loss: 1.779707
# (Time 32.56 sec; Iteration 3611 / 40000) loss: 1.868666
# (Time 32.65 sec; Iteration 3621 / 40000) loss: 1.827287
# (Time 32.75 sec; Iteration 3631 / 40000) loss: 1.832490
# (Time 32.84 sec; Iteration 3641 / 40000) loss: 1.740940
# (Time 32.93 sec; Iteration 3651 / 40000) loss: 1.803165
# (Time 33.02 sec; Iteration 3661 / 40000) loss: 1.770938
# (Time 33.11 sec; Iteration 3671 / 40000) loss: 1.709626
# (Time 33.21 sec; Iteration 3681 / 40000) loss: 1.777587
# (Time 33.31 sec; Iteration 3691 / 40000) loss: 1.763513
# (Time 33.40 sec; Iteration 3701 / 40000) loss: 1.718490
# (Time 33.49 sec; Iteration 3711 / 40000) loss: 1.909690
# (Time 33.58 sec; Iteration 3721 / 40000) loss: 1.812568
# (Time 33.67 sec; Iteration 3731 / 40000) loss: 1.895909
# (Time 33.76 sec; Iteration 3741 / 40000) loss: 1.748137
# (Time 33.85 sec; Iteration 3751 / 40000) loss: 1.686022
# (Time 33.94 sec; Iteration 3761 / 40000) loss: 1.622934
# (Time 34.04 sec; Iteration 3771 / 40000) loss: 1.786857
# (Time 34.13 sec; Iteration 3781 / 40000) loss: 1.775720
# (Time 34.22 sec; Iteration 3791 / 40000) loss: 1.740336
# (Time 34.32 sec; Iteration 3801 / 40000) loss: 1.952621
# (Time 34.41 sec; Iteration 3811 / 40000) loss: 1.709381
# (Time 34.50 sec; Iteration 3821 / 40000) loss: 1.805257
# (Time 34.59 sec; Iteration 3831 / 40000) loss: 1.797082
# (Time 34.69 sec; Iteration 3841 / 40000) loss: 1.751657
# (Time 34.78 sec; Iteration 3851 / 40000) loss: 1.608969
# (Time 34.88 sec; Iteration 3861 / 40000) loss: 1.994731
# (Time 34.97 sec; Iteration 3871 / 40000) loss: 1.862452
# (Time 35.06 sec; Iteration 3881 / 40000) loss: 1.792141
# (Time 35.15 sec; Iteration 3891 / 40000) loss: 1.783099
# (Time 35.25 sec; Iteration 3901 / 40000) loss: 1.916692
# (Time 35.35 sec; Iteration 3911 / 40000) loss: 1.756816
# (Time 35.44 sec; Iteration 3921 / 40000) loss: 1.703376
# (Time 35.53 sec; Iteration 3931 / 40000) loss: 1.838459
# (Time 35.63 sec; Iteration 3941 / 40000) loss: 1.632639
# (Time 35.73 sec; Iteration 3951 / 40000) loss: 1.824566
# (Time 35.82 sec; Iteration 3961 / 40000) loss: 1.669087
# (Time 35.92 sec; Iteration 3971 / 40000) loss: 1.881770
# (Time 36.01 sec; Iteration 3981 / 40000) loss: 1.852673
# (Time 36.10 sec; Iteration 3991 / 40000) loss: 1.781770
# (Epoch 10 / 100) train acc: 0.372000; val_acc: 0.363800
# (Time 36.46 sec; Iteration 4001 / 40000) loss: 1.905079
# (Time 36.56 sec; Iteration 4011 / 40000) loss: 1.909938
# (Time 36.65 sec; Iteration 4021 / 40000) loss: 1.859741
# (Time 36.75 sec; Iteration 4031 / 40000) loss: 1.833840
# (Time 36.84 sec; Iteration 4041 / 40000) loss: 1.793112
# (Time 36.94 sec; Iteration 4051 / 40000) loss: 1.793761
# (Time 37.03 sec; Iteration 4061 / 40000) loss: 1.619186
# (Time 37.12 sec; Iteration 4071 / 40000) loss: 1.688131
# (Time 37.21 sec; Iteration 4081 / 40000) loss: 1.821595
# (Time 37.30 sec; Iteration 4091 / 40000) loss: 1.761061
# (Time 37.39 sec; Iteration 4101 / 40000) loss: 1.766157
# (Time 37.49 sec; Iteration 4111 / 40000) loss: 1.630049
# (Time 37.58 sec; Iteration 4121 / 40000) loss: 1.790220
# (Time 37.68 sec; Iteration 4131 / 40000) loss: 1.756537
# (Time 37.77 sec; Iteration 4141 / 40000) loss: 1.703421
# (Time 37.87 sec; Iteration 4151 / 40000) loss: 1.733671
# (Time 37.96 sec; Iteration 4161 / 40000) loss: 1.726650
# (Time 38.06 sec; Iteration 4171 / 40000) loss: 1.660917
# (Time 38.15 sec; Iteration 4181 / 40000) loss: 1.844009
# (Time 38.25 sec; Iteration 4191 / 40000) loss: 1.763008
# (Time 38.34 sec; Iteration 4201 / 40000) loss: 1.787486
# (Time 38.44 sec; Iteration 4211 / 40000) loss: 1.786381
# (Time 38.54 sec; Iteration 4221 / 40000) loss: 1.781160
# (Time 38.64 sec; Iteration 4231 / 40000) loss: 1.709097
# (Time 38.74 sec; Iteration 4241 / 40000) loss: 1.597121
# (Time 38.84 sec; Iteration 4251 / 40000) loss: 1.738525
# (Time 38.93 sec; Iteration 4261 / 40000) loss: 1.890785
# (Time 39.03 sec; Iteration 4271 / 40000) loss: 1.675069
# (Time 39.12 sec; Iteration 4281 / 40000) loss: 1.743560
# (Time 39.22 sec; Iteration 4291 / 40000) loss: 1.690817
# (Time 39.32 sec; Iteration 4301 / 40000) loss: 1.681673
# (Time 39.41 sec; Iteration 4311 / 40000) loss: 1.871562
# (Time 39.50 sec; Iteration 4321 / 40000) loss: 1.621818
# (Time 39.60 sec; Iteration 4331 / 40000) loss: 1.561843
# (Time 39.70 sec; Iteration 4341 / 40000) loss: 1.838263
# (Time 39.79 sec; Iteration 4351 / 40000) loss: 1.733136
# (Time 39.89 sec; Iteration 4361 / 40000) loss: 1.806439
# (Time 39.99 sec; Iteration 4371 / 40000) loss: 1.730045
# (Time 40.08 sec; Iteration 4381 / 40000) loss: 1.554022
# (Time 40.17 sec; Iteration 4391 / 40000) loss: 1.590235
# (Epoch 11 / 100) train acc: 0.385000; val_acc: 0.370500
# (Time 40.53 sec; Iteration 4401 / 40000) loss: 1.854885
# (Time 40.63 sec; Iteration 4411 / 40000) loss: 1.729162
# (Time 40.72 sec; Iteration 4421 / 40000) loss: 1.716802
# (Time 40.82 sec; Iteration 4431 / 40000) loss: 1.653369
# (Time 40.91 sec; Iteration 4441 / 40000) loss: 1.706667
# (Time 41.00 sec; Iteration 4451 / 40000) loss: 1.720315
# (Time 41.10 sec; Iteration 4461 / 40000) loss: 1.858203
# (Time 41.19 sec; Iteration 4471 / 40000) loss: 1.771514
# (Time 41.30 sec; Iteration 4481 / 40000) loss: 1.710776
# (Time 41.39 sec; Iteration 4491 / 40000) loss: 1.681082
# (Time 41.49 sec; Iteration 4501 / 40000) loss: 1.763068
# (Time 41.58 sec; Iteration 4511 / 40000) loss: 1.777215
# (Time 41.68 sec; Iteration 4521 / 40000) loss: 1.747915
# (Time 41.78 sec; Iteration 4531 / 40000) loss: 1.717342
# (Time 41.88 sec; Iteration 4541 / 40000) loss: 1.713532
# (Time 41.98 sec; Iteration 4551 / 40000) loss: 1.739818
# (Time 42.08 sec; Iteration 4561 / 40000) loss: 1.666975
# (Time 42.17 sec; Iteration 4571 / 40000) loss: 1.585227
# (Time 42.26 sec; Iteration 4581 / 40000) loss: 1.781840
# (Time 42.36 sec; Iteration 4591 / 40000) loss: 1.830240
# (Time 42.46 sec; Iteration 4601 / 40000) loss: 1.690670
# (Time 42.56 sec; Iteration 4611 / 40000) loss: 1.663142
# (Time 42.65 sec; Iteration 4621 / 40000) loss: 1.644899
# (Time 42.75 sec; Iteration 4631 / 40000) loss: 1.647082
# (Time 42.84 sec; Iteration 4641 / 40000) loss: 1.744355
# (Time 42.94 sec; Iteration 4651 / 40000) loss: 1.714532
# (Time 43.03 sec; Iteration 4661 / 40000) loss: 1.588174
# (Time 43.12 sec; Iteration 4671 / 40000) loss: 1.654150
# (Time 43.22 sec; Iteration 4681 / 40000) loss: 1.735846
# (Time 43.31 sec; Iteration 4691 / 40000) loss: 1.701731
# (Time 43.41 sec; Iteration 4701 / 40000) loss: 1.739082
# (Time 43.50 sec; Iteration 4711 / 40000) loss: 1.840448
# (Time 43.59 sec; Iteration 4721 / 40000) loss: 1.629397
# (Time 43.68 sec; Iteration 4731 / 40000) loss: 1.961825
# (Time 43.79 sec; Iteration 4741 / 40000) loss: 1.733789
# (Time 43.88 sec; Iteration 4751 / 40000) loss: 1.629555
# (Time 43.97 sec; Iteration 4761 / 40000) loss: 1.644671
# (Time 44.06 sec; Iteration 4771 / 40000) loss: 1.793969
# (Time 44.15 sec; Iteration 4781 / 40000) loss: 1.876546
# (Time 44.25 sec; Iteration 4791 / 40000) loss: 1.680919
# (Epoch 12 / 100) train acc: 0.389000; val_acc: 0.377300
# (Time 44.61 sec; Iteration 4801 / 40000) loss: 1.726644
# (Time 44.70 sec; Iteration 4811 / 40000) loss: 1.693593
# (Time 44.80 sec; Iteration 4821 / 40000) loss: 1.594658
# (Time 44.89 sec; Iteration 4831 / 40000) loss: 1.624247
# (Time 44.98 sec; Iteration 4841 / 40000) loss: 1.713121
# (Time 45.07 sec; Iteration 4851 / 40000) loss: 1.740569
# (Time 45.17 sec; Iteration 4861 / 40000) loss: 1.701854
# (Time 45.26 sec; Iteration 4871 / 40000) loss: 1.656267
# (Time 45.36 sec; Iteration 4881 / 40000) loss: 1.733311
# (Time 45.45 sec; Iteration 4891 / 40000) loss: 1.579133
# (Time 45.55 sec; Iteration 4901 / 40000) loss: 1.813093
# (Time 45.64 sec; Iteration 4911 / 40000) loss: 1.669096
# (Time 45.74 sec; Iteration 4921 / 40000) loss: 1.676377
# (Time 45.83 sec; Iteration 4931 / 40000) loss: 1.444706
# (Time 45.93 sec; Iteration 4941 / 40000) loss: 1.737751
# (Time 46.03 sec; Iteration 4951 / 40000) loss: 1.674799
# (Time 46.12 sec; Iteration 4961 / 40000) loss: 1.679836
# (Time 46.22 sec; Iteration 4971 / 40000) loss: 1.836086
# (Time 46.31 sec; Iteration 4981 / 40000) loss: 1.762854
# (Time 46.40 sec; Iteration 4991 / 40000) loss: 1.784906
# (Time 46.49 sec; Iteration 5001 / 40000) loss: 1.540848
# (Time 46.59 sec; Iteration 5011 / 40000) loss: 1.661371
# (Time 46.68 sec; Iteration 5021 / 40000) loss: 1.842328
# (Time 46.77 sec; Iteration 5031 / 40000) loss: 1.780850
# (Time 46.86 sec; Iteration 5041 / 40000) loss: 1.803643
# (Time 46.96 sec; Iteration 5051 / 40000) loss: 1.587976
# (Time 47.05 sec; Iteration 5061 / 40000) loss: 1.692243
# (Time 47.14 sec; Iteration 5071 / 40000) loss: 1.681871
# (Time 47.24 sec; Iteration 5081 / 40000) loss: 1.761747
# (Time 47.33 sec; Iteration 5091 / 40000) loss: 1.686981
# (Time 47.43 sec; Iteration 5101 / 40000) loss: 1.714692
# (Time 47.52 sec; Iteration 5111 / 40000) loss: 1.812335
# (Time 47.61 sec; Iteration 5121 / 40000) loss: 1.674957
# (Time 47.71 sec; Iteration 5131 / 40000) loss: 1.663145
# (Time 47.80 sec; Iteration 5141 / 40000) loss: 1.761241
# (Time 47.90 sec; Iteration 5151 / 40000) loss: 1.631369
# (Time 47.99 sec; Iteration 5161 / 40000) loss: 1.669736
# (Time 48.08 sec; Iteration 5171 / 40000) loss: 1.599157
# (Time 48.18 sec; Iteration 5181 / 40000) loss: 1.724130
# (Time 48.27 sec; Iteration 5191 / 40000) loss: 1.728913
# (Epoch 13 / 100) train acc: 0.395000; val_acc: 0.384900
# (Time 48.63 sec; Iteration 5201 / 40000) loss: 1.711361
# (Time 48.73 sec; Iteration 5211 / 40000) loss: 1.457890
# (Time 48.83 sec; Iteration 5221 / 40000) loss: 1.765487
# (Time 48.92 sec; Iteration 5231 / 40000) loss: 1.674138
# (Time 49.02 sec; Iteration 5241 / 40000) loss: 1.813878
# (Time 49.11 sec; Iteration 5251 / 40000) loss: 1.651085
# (Time 49.21 sec; Iteration 5261 / 40000) loss: 1.755835
# (Time 49.30 sec; Iteration 5271 / 40000) loss: 1.679763
# (Time 49.39 sec; Iteration 5281 / 40000) loss: 1.578895
# (Time 49.49 sec; Iteration 5291 / 40000) loss: 1.590517
# (Time 49.58 sec; Iteration 5301 / 40000) loss: 1.801642
# (Time 49.68 sec; Iteration 5311 / 40000) loss: 1.601190
# (Time 49.77 sec; Iteration 5321 / 40000) loss: 1.750850
# (Time 49.87 sec; Iteration 5331 / 40000) loss: 1.606643
# (Time 49.96 sec; Iteration 5341 / 40000) loss: 1.809646
# (Time 50.06 sec; Iteration 5351 / 40000) loss: 1.650865
# (Time 50.16 sec; Iteration 5361 / 40000) loss: 1.617602
# (Time 50.25 sec; Iteration 5371 / 40000) loss: 1.554809
# (Time 50.35 sec; Iteration 5381 / 40000) loss: 1.723453
# (Time 50.44 sec; Iteration 5391 / 40000) loss: 1.614859
# (Time 50.54 sec; Iteration 5401 / 40000) loss: 1.743399
# (Time 50.64 sec; Iteration 5411 / 40000) loss: 1.672355
# (Time 50.74 sec; Iteration 5421 / 40000) loss: 1.685664
# (Time 50.84 sec; Iteration 5431 / 40000) loss: 1.614695
# (Time 50.94 sec; Iteration 5441 / 40000) loss: 1.678663
# (Time 51.03 sec; Iteration 5451 / 40000) loss: 1.590298
# (Time 51.13 sec; Iteration 5461 / 40000) loss: 1.718344
# (Time 51.22 sec; Iteration 5471 / 40000) loss: 1.715399
# (Time 51.32 sec; Iteration 5481 / 40000) loss: 1.761269
# (Time 51.41 sec; Iteration 5491 / 40000) loss: 1.580667
# (Time 51.51 sec; Iteration 5501 / 40000) loss: 1.522380
# (Time 51.60 sec; Iteration 5511 / 40000) loss: 1.639963
# (Time 51.69 sec; Iteration 5521 / 40000) loss: 1.663194
# (Time 51.79 sec; Iteration 5531 / 40000) loss: 1.656441
# (Time 51.88 sec; Iteration 5541 / 40000) loss: 1.602503
# (Time 51.98 sec; Iteration 5551 / 40000) loss: 1.685969
# (Time 52.07 sec; Iteration 5561 / 40000) loss: 1.736327
# (Time 52.16 sec; Iteration 5571 / 40000) loss: 1.848226
# (Time 52.26 sec; Iteration 5581 / 40000) loss: 1.672476
# (Time 52.35 sec; Iteration 5591 / 40000) loss: 1.773239
# (Epoch 14 / 100) train acc: 0.411000; val_acc: 0.395100
# (Time 52.71 sec; Iteration 5601 / 40000) loss: 1.639634
# (Time 52.80 sec; Iteration 5611 / 40000) loss: 1.519739
# (Time 52.89 sec; Iteration 5621 / 40000) loss: 1.563927
# (Time 52.99 sec; Iteration 5631 / 40000) loss: 1.430396
# (Time 53.09 sec; Iteration 5641 / 40000) loss: 1.712908
# (Time 53.18 sec; Iteration 5651 / 40000) loss: 1.624869
# (Time 53.28 sec; Iteration 5661 / 40000) loss: 1.458106
# (Time 53.37 sec; Iteration 5671 / 40000) loss: 1.639246
# (Time 53.47 sec; Iteration 5681 / 40000) loss: 1.788177
# (Time 53.56 sec; Iteration 5691 / 40000) loss: 1.522289
# (Time 53.66 sec; Iteration 5701 / 40000) loss: 1.511498
# (Time 53.76 sec; Iteration 5711 / 40000) loss: 1.657594
# (Time 53.85 sec; Iteration 5721 / 40000) loss: 1.576097
# (Time 53.95 sec; Iteration 5731 / 40000) loss: 1.670550
# (Time 54.05 sec; Iteration 5741 / 40000) loss: 1.643141
# (Time 54.15 sec; Iteration 5751 / 40000) loss: 1.562147
# (Time 54.25 sec; Iteration 5761 / 40000) loss: 1.732563
# (Time 54.34 sec; Iteration 5771 / 40000) loss: 1.691169
# (Time 54.44 sec; Iteration 5781 / 40000) loss: 1.600385
# (Time 54.53 sec; Iteration 5791 / 40000) loss: 1.508778
# (Time 54.63 sec; Iteration 5801 / 40000) loss: 1.716894
# (Time 54.73 sec; Iteration 5811 / 40000) loss: 1.701868
# (Time 54.82 sec; Iteration 5821 / 40000) loss: 1.546415
# (Time 54.92 sec; Iteration 5831 / 40000) loss: 1.718039
# (Time 55.01 sec; Iteration 5841 / 40000) loss: 1.814113
# (Time 55.11 sec; Iteration 5851 / 40000) loss: 1.641120
# (Time 55.20 sec; Iteration 5861 / 40000) loss: 1.609424
# (Time 55.30 sec; Iteration 5871 / 40000) loss: 1.623571
# (Time 55.39 sec; Iteration 5881 / 40000) loss: 1.629321
# (Time 55.49 sec; Iteration 5891 / 40000) loss: 1.718021
# (Time 55.58 sec; Iteration 5901 / 40000) loss: 1.744932
# (Time 55.68 sec; Iteration 5911 / 40000) loss: 1.591824
# (Time 55.77 sec; Iteration 5921 / 40000) loss: 1.710735
# (Time 55.87 sec; Iteration 5931 / 40000) loss: 1.853015
# (Time 55.96 sec; Iteration 5941 / 40000) loss: 1.668690
# (Time 56.05 sec; Iteration 5951 / 40000) loss: 1.652733
# (Time 56.15 sec; Iteration 5961 / 40000) loss: 1.648901
# (Time 56.25 sec; Iteration 5971 / 40000) loss: 1.697565
# (Time 56.34 sec; Iteration 5981 / 40000) loss: 1.706865
# (Time 56.44 sec; Iteration 5991 / 40000) loss: 1.580420
# (Epoch 15 / 100) train acc: 0.419000; val_acc: 0.401400
# (Time 56.80 sec; Iteration 6001 / 40000) loss: 1.707442
# (Time 56.89 sec; Iteration 6011 / 40000) loss: 1.619264
# (Time 56.99 sec; Iteration 6021 / 40000) loss: 1.635391
# (Time 57.09 sec; Iteration 6031 / 40000) loss: 1.551899
# (Time 57.18 sec; Iteration 6041 / 40000) loss: 1.601241
# (Time 57.27 sec; Iteration 6051 / 40000) loss: 1.710113
# (Time 57.37 sec; Iteration 6061 / 40000) loss: 1.795684
# (Time 57.47 sec; Iteration 6071 / 40000) loss: 1.524999
# (Time 57.56 sec; Iteration 6081 / 40000) loss: 1.649706
# (Time 57.66 sec; Iteration 6091 / 40000) loss: 1.622664
# (Time 57.76 sec; Iteration 6101 / 40000) loss: 1.716064
# (Time 57.85 sec; Iteration 6111 / 40000) loss: 1.670200
# (Time 57.95 sec; Iteration 6121 / 40000) loss: 1.654931
# (Time 58.05 sec; Iteration 6131 / 40000) loss: 1.607462
# (Time 58.15 sec; Iteration 6141 / 40000) loss: 1.670256
# (Time 58.24 sec; Iteration 6151 / 40000) loss: 1.601835
# (Time 58.34 sec; Iteration 6161 / 40000) loss: 1.550824
# (Time 58.43 sec; Iteration 6171 / 40000) loss: 1.681888
# (Time 58.52 sec; Iteration 6181 / 40000) loss: 1.611010
# (Time 58.62 sec; Iteration 6191 / 40000) loss: 1.607984
# (Time 58.72 sec; Iteration 6201 / 40000) loss: 1.597501
# (Time 58.82 sec; Iteration 6211 / 40000) loss: 1.725817
# (Time 58.92 sec; Iteration 6221 / 40000) loss: 1.436162
# (Time 59.01 sec; Iteration 6231 / 40000) loss: 1.773514
# (Time 59.11 sec; Iteration 6241 / 40000) loss: 1.643298
# (Time 59.21 sec; Iteration 6251 / 40000) loss: 1.678239
# (Time 59.30 sec; Iteration 6261 / 40000) loss: 1.754384
# (Time 59.40 sec; Iteration 6271 / 40000) loss: 1.586468
# (Time 59.49 sec; Iteration 6281 / 40000) loss: 1.557295
# (Time 59.59 sec; Iteration 6291 / 40000) loss: 1.608259
# (Time 59.69 sec; Iteration 6301 / 40000) loss: 1.639202
# (Time 59.78 sec; Iteration 6311 / 40000) loss: 1.680334
# (Time 59.88 sec; Iteration 6321 / 40000) loss: 1.544956
# (Time 59.98 sec; Iteration 6331 / 40000) loss: 1.600100
# (Time 60.07 sec; Iteration 6341 / 40000) loss: 1.633670
# (Time 60.17 sec; Iteration 6351 / 40000) loss: 1.688466
# (Time 60.27 sec; Iteration 6361 / 40000) loss: 1.593657
# (Time 60.36 sec; Iteration 6371 / 40000) loss: 1.706706
# (Time 60.45 sec; Iteration 6381 / 40000) loss: 1.653469
# (Time 60.55 sec; Iteration 6391 / 40000) loss: 1.636504
# (Epoch 16 / 100) train acc: 0.401000; val_acc: 0.410100
# (Time 60.91 sec; Iteration 6401 / 40000) loss: 1.720841
# (Time 61.01 sec; Iteration 6411 / 40000) loss: 1.755543
# (Time 61.10 sec; Iteration 6421 / 40000) loss: 1.641826
# (Time 61.19 sec; Iteration 6431 / 40000) loss: 1.607024
# (Time 61.28 sec; Iteration 6441 / 40000) loss: 1.819108
# (Time 61.37 sec; Iteration 6451 / 40000) loss: 1.474891
# (Time 61.47 sec; Iteration 6461 / 40000) loss: 1.697741
# (Time 61.56 sec; Iteration 6471 / 40000) loss: 1.663726
# (Time 61.65 sec; Iteration 6481 / 40000) loss: 1.556033
# (Time 61.74 sec; Iteration 6491 / 40000) loss: 1.618209
# (Time 61.84 sec; Iteration 6501 / 40000) loss: 1.453089
# (Time 61.93 sec; Iteration 6511 / 40000) loss: 1.791413
# (Time 62.02 sec; Iteration 6521 / 40000) loss: 1.627539
# (Time 62.11 sec; Iteration 6531 / 40000) loss: 1.501856
# (Time 62.21 sec; Iteration 6541 / 40000) loss: 1.531955
# (Time 62.30 sec; Iteration 6551 / 40000) loss: 1.641503
# (Time 62.39 sec; Iteration 6561 / 40000) loss: 1.619547
# (Time 62.49 sec; Iteration 6571 / 40000) loss: 1.614804
# (Time 62.59 sec; Iteration 6581 / 40000) loss: 1.687621
# (Time 62.69 sec; Iteration 6591 / 40000) loss: 1.622777
# (Time 62.78 sec; Iteration 6601 / 40000) loss: 1.638761
# (Time 62.88 sec; Iteration 6611 / 40000) loss: 1.604197
# (Time 62.97 sec; Iteration 6621 / 40000) loss: 1.694800
# (Time 63.07 sec; Iteration 6631 / 40000) loss: 1.700022
# (Time 63.17 sec; Iteration 6641 / 40000) loss: 1.592776
# (Time 63.27 sec; Iteration 6651 / 40000) loss: 1.549454
# (Time 63.36 sec; Iteration 6661 / 40000) loss: 1.622417
# (Time 63.46 sec; Iteration 6671 / 40000) loss: 1.653004
# (Time 63.55 sec; Iteration 6681 / 40000) loss: 1.690910
# (Time 63.65 sec; Iteration 6691 / 40000) loss: 1.596880
# (Time 63.75 sec; Iteration 6701 / 40000) loss: 1.536182
# (Time 63.85 sec; Iteration 6711 / 40000) loss: 1.570079
# (Time 63.95 sec; Iteration 6721 / 40000) loss: 1.763782
# (Time 64.05 sec; Iteration 6731 / 40000) loss: 1.765684
# (Time 64.14 sec; Iteration 6741 / 40000) loss: 1.621954
# (Time 64.24 sec; Iteration 6751 / 40000) loss: 1.783329
# (Time 64.33 sec; Iteration 6761 / 40000) loss: 1.531241
# (Time 64.43 sec; Iteration 6771 / 40000) loss: 1.540595
# (Time 64.53 sec; Iteration 6781 / 40000) loss: 1.716112
# (Time 64.63 sec; Iteration 6791 / 40000) loss: 1.748434
# (Epoch 17 / 100) train acc: 0.436000; val_acc: 0.416100
# (Time 64.99 sec; Iteration 6801 / 40000) loss: 1.606787
# (Time 65.08 sec; Iteration 6811 / 40000) loss: 1.608400
# (Time 65.18 sec; Iteration 6821 / 40000) loss: 1.547825
# (Time 65.27 sec; Iteration 6831 / 40000) loss: 1.532258
# (Time 65.37 sec; Iteration 6841 / 40000) loss: 1.778828
# (Time 65.46 sec; Iteration 6851 / 40000) loss: 1.500919
# (Time 65.56 sec; Iteration 6861 / 40000) loss: 1.629699
# (Time 65.65 sec; Iteration 6871 / 40000) loss: 1.590730
# (Time 65.74 sec; Iteration 6881 / 40000) loss: 1.756933
# (Time 65.84 sec; Iteration 6891 / 40000) loss: 1.620331
# (Time 65.93 sec; Iteration 6901 / 40000) loss: 1.723768
# (Time 66.03 sec; Iteration 6911 / 40000) loss: 1.605915
# (Time 66.13 sec; Iteration 6921 / 40000) loss: 1.578190
# (Time 66.22 sec; Iteration 6931 / 40000) loss: 1.617339
# (Time 66.32 sec; Iteration 6941 / 40000) loss: 1.527316
# (Time 66.42 sec; Iteration 6951 / 40000) loss: 1.619877
# (Time 66.51 sec; Iteration 6961 / 40000) loss: 1.690653
# (Time 66.62 sec; Iteration 6971 / 40000) loss: 1.568636
# (Time 66.71 sec; Iteration 6981 / 40000) loss: 1.641677
# (Time 66.80 sec; Iteration 6991 / 40000) loss: 1.509192
# (Time 66.90 sec; Iteration 7001 / 40000) loss: 1.570963
# (Time 66.99 sec; Iteration 7011 / 40000) loss: 1.571781
# (Time 67.08 sec; Iteration 7021 / 40000) loss: 1.572249
# (Time 67.17 sec; Iteration 7031 / 40000) loss: 1.659520
# (Time 67.26 sec; Iteration 7041 / 40000) loss: 1.554659
# (Time 67.36 sec; Iteration 7051 / 40000) loss: 1.461649
# (Time 67.46 sec; Iteration 7061 / 40000) loss: 1.662860
# (Time 67.55 sec; Iteration 7071 / 40000) loss: 1.654821
# (Time 67.64 sec; Iteration 7081 / 40000) loss: 1.641757
# (Time 67.74 sec; Iteration 7091 / 40000) loss: 1.542899
# (Time 67.83 sec; Iteration 7101 / 40000) loss: 1.593014
# (Time 67.92 sec; Iteration 7111 / 40000) loss: 1.424592
# (Time 68.02 sec; Iteration 7121 / 40000) loss: 1.470987
# (Time 68.11 sec; Iteration 7131 / 40000) loss: 1.671594
# (Time 68.20 sec; Iteration 7141 / 40000) loss: 1.686087
# (Time 68.29 sec; Iteration 7151 / 40000) loss: 1.608142
# (Time 68.39 sec; Iteration 7161 / 40000) loss: 1.622118
# (Time 68.49 sec; Iteration 7171 / 40000) loss: 1.642049
# (Time 68.58 sec; Iteration 7181 / 40000) loss: 1.736364
# (Time 68.68 sec; Iteration 7191 / 40000) loss: 1.497277
# (Epoch 18 / 100) train acc: 0.412000; val_acc: 0.423800
# (Time 69.04 sec; Iteration 7201 / 40000) loss: 1.577296
# (Time 69.14 sec; Iteration 7211 / 40000) loss: 1.525750
# (Time 69.23 sec; Iteration 7221 / 40000) loss: 1.665060
# (Time 69.32 sec; Iteration 7231 / 40000) loss: 1.527550
# (Time 69.42 sec; Iteration 7241 / 40000) loss: 1.575191
# (Time 69.51 sec; Iteration 7251 / 40000) loss: 1.653309
# (Time 69.60 sec; Iteration 7261 / 40000) loss: 1.573600
# (Time 69.70 sec; Iteration 7271 / 40000) loss: 1.597467
# (Time 69.79 sec; Iteration 7281 / 40000) loss: 1.570311
# (Time 69.88 sec; Iteration 7291 / 40000) loss: 1.675056
# (Time 69.97 sec; Iteration 7301 / 40000) loss: 1.723149
# (Time 70.06 sec; Iteration 7311 / 40000) loss: 1.682186
# (Time 70.16 sec; Iteration 7321 / 40000) loss: 1.665430
# (Time 70.25 sec; Iteration 7331 / 40000) loss: 1.614682
# (Time 70.34 sec; Iteration 7341 / 40000) loss: 1.582138
# (Time 70.43 sec; Iteration 7351 / 40000) loss: 1.607385
# (Time 70.53 sec; Iteration 7361 / 40000) loss: 1.611701
# (Time 70.62 sec; Iteration 7371 / 40000) loss: 1.664737
# (Time 70.71 sec; Iteration 7381 / 40000) loss: 1.650788
# (Time 70.81 sec; Iteration 7391 / 40000) loss: 1.727539
# (Time 70.90 sec; Iteration 7401 / 40000) loss: 1.492930
# (Time 71.00 sec; Iteration 7411 / 40000) loss: 1.537692
# (Time 71.09 sec; Iteration 7421 / 40000) loss: 1.529687
# (Time 71.18 sec; Iteration 7431 / 40000) loss: 1.601063
# (Time 71.27 sec; Iteration 7441 / 40000) loss: 1.587942
# (Time 71.37 sec; Iteration 7451 / 40000) loss: 1.524499
# (Time 71.46 sec; Iteration 7461 / 40000) loss: 1.738130
# (Time 71.56 sec; Iteration 7471 / 40000) loss: 1.495285
# (Time 71.65 sec; Iteration 7481 / 40000) loss: 1.669759
# (Time 71.74 sec; Iteration 7491 / 40000) loss: 1.818423
# (Time 71.83 sec; Iteration 7501 / 40000) loss: 1.550843
# (Time 71.92 sec; Iteration 7511 / 40000) loss: 1.407488
# (Time 72.01 sec; Iteration 7521 / 40000) loss: 1.672404
# (Time 72.11 sec; Iteration 7531 / 40000) loss: 1.512628
# (Time 72.20 sec; Iteration 7541 / 40000) loss: 1.595071
# (Time 72.29 sec; Iteration 7551 / 40000) loss: 1.596884
# (Time 72.38 sec; Iteration 7561 / 40000) loss: 1.760697
# (Time 72.47 sec; Iteration 7571 / 40000) loss: 1.483239
# (Time 72.57 sec; Iteration 7581 / 40000) loss: 1.750541
# (Time 72.66 sec; Iteration 7591 / 40000) loss: 1.543024
# (Epoch 19 / 100) train acc: 0.425000; val_acc: 0.428300
# (Time 73.02 sec; Iteration 7601 / 40000) loss: 1.681619
# (Time 73.11 sec; Iteration 7611 / 40000) loss: 1.521049
# (Time 73.20 sec; Iteration 7621 / 40000) loss: 1.630067
# (Time 73.29 sec; Iteration 7631 / 40000) loss: 1.648626
# (Time 73.38 sec; Iteration 7641 / 40000) loss: 1.524572
# (Time 73.48 sec; Iteration 7651 / 40000) loss: 1.522201
# (Time 73.57 sec; Iteration 7661 / 40000) loss: 1.665626
# (Time 73.66 sec; Iteration 7671 / 40000) loss: 1.490902
# (Time 73.76 sec; Iteration 7681 / 40000) loss: 1.559339
# (Time 73.85 sec; Iteration 7691 / 40000) loss: 1.608940
# (Time 73.95 sec; Iteration 7701 / 40000) loss: 1.613384
# (Time 74.04 sec; Iteration 7711 / 40000) loss: 1.583994
# (Time 74.13 sec; Iteration 7721 / 40000) loss: 1.553654
# (Time 74.22 sec; Iteration 7731 / 40000) loss: 1.624186
# (Time 74.31 sec; Iteration 7741 / 40000) loss: 1.699981
# (Time 74.40 sec; Iteration 7751 / 40000) loss: 1.533887
# (Time 74.49 sec; Iteration 7761 / 40000) loss: 1.568807
# (Time 74.58 sec; Iteration 7771 / 40000) loss: 1.669884
# (Time 74.67 sec; Iteration 7781 / 40000) loss: 1.490671
# (Time 74.77 sec; Iteration 7791 / 40000) loss: 1.706674
# (Time 74.86 sec; Iteration 7801 / 40000) loss: 1.491159
# (Time 74.97 sec; Iteration 7811 / 40000) loss: 1.633223
# (Time 75.06 sec; Iteration 7821 / 40000) loss: 1.536516
# (Time 75.15 sec; Iteration 7831 / 40000) loss: 1.618732
# (Time 75.24 sec; Iteration 7841 / 40000) loss: 1.526267
# (Time 75.33 sec; Iteration 7851 / 40000) loss: 1.550642
# (Time 75.43 sec; Iteration 7861 / 40000) loss: 1.576717
# (Time 75.52 sec; Iteration 7871 / 40000) loss: 1.446334
# (Time 75.61 sec; Iteration 7881 / 40000) loss: 1.697923
# (Time 75.70 sec; Iteration 7891 / 40000) loss: 1.663705
# (Time 75.80 sec; Iteration 7901 / 40000) loss: 1.583287
# (Time 75.89 sec; Iteration 7911 / 40000) loss: 1.648989
# (Time 75.98 sec; Iteration 7921 / 40000) loss: 1.649331
# (Time 76.07 sec; Iteration 7931 / 40000) loss: 1.633765
# (Time 76.16 sec; Iteration 7941 / 40000) loss: 1.731421
# (Time 76.25 sec; Iteration 7951 / 40000) loss: 1.670378
# (Time 76.34 sec; Iteration 7961 / 40000) loss: 1.518757
# (Time 76.43 sec; Iteration 7971 / 40000) loss: 1.635623
# (Time 76.52 sec; Iteration 7981 / 40000) loss: 1.537057
# (Time 76.61 sec; Iteration 7991 / 40000) loss: 1.557803
# (Epoch 20 / 100) train acc: 0.458000; val_acc: 0.431500
# (Time 76.97 sec; Iteration 8001 / 40000) loss: 1.504814
# (Time 77.06 sec; Iteration 8011 / 40000) loss: 1.574355
# (Time 77.15 sec; Iteration 8021 / 40000) loss: 1.665886
# (Time 77.24 sec; Iteration 8031 / 40000) loss: 1.535387
# (Time 77.33 sec; Iteration 8041 / 40000) loss: 1.742818
# (Time 77.42 sec; Iteration 8051 / 40000) loss: 1.659966
# (Time 77.52 sec; Iteration 8061 / 40000) loss: 1.687615
# (Time 77.61 sec; Iteration 8071 / 40000) loss: 1.606263
# (Time 77.70 sec; Iteration 8081 / 40000) loss: 1.679472
# (Time 77.79 sec; Iteration 8091 / 40000) loss: 1.652732
# (Time 77.89 sec; Iteration 8101 / 40000) loss: 1.572095
# (Time 77.98 sec; Iteration 8111 / 40000) loss: 1.502034
# (Time 78.08 sec; Iteration 8121 / 40000) loss: 1.445113
# (Time 78.17 sec; Iteration 8131 / 40000) loss: 1.584511
# (Time 78.26 sec; Iteration 8141 / 40000) loss: 1.560505
# (Time 78.35 sec; Iteration 8151 / 40000) loss: 1.650838
# (Time 78.44 sec; Iteration 8161 / 40000) loss: 1.552015
# (Time 78.53 sec; Iteration 8171 / 40000) loss: 1.729786
# (Time 78.62 sec; Iteration 8181 / 40000) loss: 1.606961
# (Time 78.71 sec; Iteration 8191 / 40000) loss: 1.622304
# (Time 78.81 sec; Iteration 8201 / 40000) loss: 1.555763
# (Time 78.90 sec; Iteration 8211 / 40000) loss: 1.676609
# (Time 78.99 sec; Iteration 8221 / 40000) loss: 1.639221
# (Time 79.08 sec; Iteration 8231 / 40000) loss: 1.643505
# (Time 79.17 sec; Iteration 8241 / 40000) loss: 1.529358
# (Time 79.26 sec; Iteration 8251 / 40000) loss: 1.530732
# (Time 79.35 sec; Iteration 8261 / 40000) loss: 1.611815
# (Time 79.44 sec; Iteration 8271 / 40000) loss: 1.663416
# (Time 79.53 sec; Iteration 8281 / 40000) loss: 1.647147
# (Time 79.63 sec; Iteration 8291 / 40000) loss: 1.452010
# (Time 79.72 sec; Iteration 8301 / 40000) loss: 1.507384
# (Time 79.80 sec; Iteration 8311 / 40000) loss: 1.687989
# (Time 79.89 sec; Iteration 8321 / 40000) loss: 1.495271
# (Time 79.98 sec; Iteration 8331 / 40000) loss: 1.537553
# (Time 80.07 sec; Iteration 8341 / 40000) loss: 1.458909
# (Time 80.15 sec; Iteration 8351 / 40000) loss: 1.659989
# (Time 80.24 sec; Iteration 8361 / 40000) loss: 1.427115
# (Time 80.33 sec; Iteration 8371 / 40000) loss: 1.589092
# (Time 80.42 sec; Iteration 8381 / 40000) loss: 1.474526
# (Time 80.51 sec; Iteration 8391 / 40000) loss: 1.615338
# ...
# (Time 365.60 sec; Iteration 37311 / 40000) loss: 1.043418
# (Time 365.69 sec; Iteration 37321 / 40000) loss: 1.057761
# (Time 365.78 sec; Iteration 37331 / 40000) loss: 1.069914
# (Time 365.87 sec; Iteration 37341 / 40000) loss: 1.109759
# (Time 365.96 sec; Iteration 37351 / 40000) loss: 0.982129
# (Time 366.05 sec; Iteration 37361 / 40000) loss: 1.072783
# (Time 366.14 sec; Iteration 37371 / 40000) loss: 0.983318
# (Time 366.24 sec; Iteration 37381 / 40000) loss: 1.059388
# (Time 366.34 sec; Iteration 37391 / 40000) loss: 1.142461
# (Time 366.43 sec; Iteration 37401 / 40000) loss: 1.049211
# (Time 366.52 sec; Iteration 37411 / 40000) loss: 0.974347
# (Time 366.61 sec; Iteration 37421 / 40000) loss: 0.921113
# (Time 366.70 sec; Iteration 37431 / 40000) loss: 1.124963
# (Time 366.80 sec; Iteration 37441 / 40000) loss: 1.085588
# (Time 366.89 sec; Iteration 37451 / 40000) loss: 0.910669
# (Time 366.98 sec; Iteration 37461 / 40000) loss: 1.070728
# (Time 367.07 sec; Iteration 37471 / 40000) loss: 0.948146
# (Time 367.17 sec; Iteration 37481 / 40000) loss: 1.019005
# (Time 367.25 sec; Iteration 37491 / 40000) loss: 1.047682
# (Time 367.34 sec; Iteration 37501 / 40000) loss: 1.119941
# (Time 367.44 sec; Iteration 37511 / 40000) loss: 1.127226
# (Time 367.53 sec; Iteration 37521 / 40000) loss: 1.118015
# (Time 367.62 sec; Iteration 37531 / 40000) loss: 1.122044
# (Time 367.71 sec; Iteration 37541 / 40000) loss: 0.993096
# (Time 367.81 sec; Iteration 37551 / 40000) loss: 1.108219
# (Time 367.90 sec; Iteration 37561 / 40000) loss: 1.194869
# (Time 367.99 sec; Iteration 37571 / 40000) loss: 1.037053
# (Time 368.08 sec; Iteration 37581 / 40000) loss: 1.014289
# (Time 368.17 sec; Iteration 37591 / 40000) loss: 1.181007
# (Epoch 94 / 100) train acc: 0.631000; val_acc: 0.527100
# (Time 368.52 sec; Iteration 37601 / 40000) loss: 1.064293
# (Time 368.61 sec; Iteration 37611 / 40000) loss: 1.195437
# (Time 368.70 sec; Iteration 37621 / 40000) loss: 1.178396
# (Time 368.79 sec; Iteration 37631 / 40000) loss: 1.027361
# (Time 368.88 sec; Iteration 37641 / 40000) loss: 1.066406
# (Time 368.98 sec; Iteration 37651 / 40000) loss: 1.023820
# (Time 369.08 sec; Iteration 37661 / 40000) loss: 0.985408
# (Time 369.17 sec; Iteration 37671 / 40000) loss: 0.955223
# (Time 369.26 sec; Iteration 37681 / 40000) loss: 0.950422
# (Time 369.35 sec; Iteration 37691 / 40000) loss: 1.169204
# (Time 369.44 sec; Iteration 37701 / 40000) loss: 1.070173
# (Time 369.53 sec; Iteration 37711 / 40000) loss: 1.095526
# (Time 369.63 sec; Iteration 37721 / 40000) loss: 0.917082
# (Time 369.72 sec; Iteration 37731 / 40000) loss: 0.946110
# (Time 369.81 sec; Iteration 37741 / 40000) loss: 1.163566
# (Time 369.90 sec; Iteration 37751 / 40000) loss: 1.195538
# (Time 369.99 sec; Iteration 37761 / 40000) loss: 0.999808
# (Time 370.08 sec; Iteration 37771 / 40000) loss: 1.142671
# (Time 370.17 sec; Iteration 37781 / 40000) loss: 1.136766
# (Time 370.27 sec; Iteration 37791 / 40000) loss: 1.166147
# (Time 370.36 sec; Iteration 37801 / 40000) loss: 1.021970
# (Time 370.45 sec; Iteration 37811 / 40000) loss: 0.852284
# (Time 370.54 sec; Iteration 37821 / 40000) loss: 1.252110
# (Time 370.63 sec; Iteration 37831 / 40000) loss: 1.087459
# (Time 370.73 sec; Iteration 37841 / 40000) loss: 1.128963
# (Time 370.82 sec; Iteration 37851 / 40000) loss: 1.143290
# (Time 370.90 sec; Iteration 37861 / 40000) loss: 1.132784
# (Time 371.00 sec; Iteration 37871 / 40000) loss: 1.040674
# (Time 371.09 sec; Iteration 37881 / 40000) loss: 1.046965
# (Time 371.18 sec; Iteration 37891 / 40000) loss: 1.274542
# (Time 371.28 sec; Iteration 37901 / 40000) loss: 0.977485
# (Time 371.37 sec; Iteration 37911 / 40000) loss: 0.953721
# (Time 371.46 sec; Iteration 37921 / 40000) loss: 0.900427
# (Time 371.55 sec; Iteration 37931 / 40000) loss: 0.975718
# (Time 371.64 sec; Iteration 37941 / 40000) loss: 1.214725
# (Time 371.73 sec; Iteration 37951 / 40000) loss: 1.036771
# (Time 371.82 sec; Iteration 37961 / 40000) loss: 1.078838
# (Time 371.91 sec; Iteration 37971 / 40000) loss: 1.040940
# (Time 372.01 sec; Iteration 37981 / 40000) loss: 0.833736
# (Time 372.10 sec; Iteration 37991 / 40000) loss: 1.156461
# (Epoch 95 / 100) train acc: 0.657000; val_acc: 0.526000
# (Time 372.46 sec; Iteration 38001 / 40000) loss: 1.006687
# (Time 372.55 sec; Iteration 38011 / 40000) loss: 0.953918
# (Time 372.64 sec; Iteration 38021 / 40000) loss: 1.275863
# (Time 372.73 sec; Iteration 38031 / 40000) loss: 1.145738
# (Time 372.82 sec; Iteration 38041 / 40000) loss: 1.065021
# (Time 372.92 sec; Iteration 38051 / 40000) loss: 1.192070
# (Time 373.01 sec; Iteration 38061 / 40000) loss: 1.127361
# (Time 373.11 sec; Iteration 38071 / 40000) loss: 0.950149
# (Time 373.19 sec; Iteration 38081 / 40000) loss: 0.944954
# (Time 373.28 sec; Iteration 38091 / 40000) loss: 0.845931
# (Time 373.38 sec; Iteration 38101 / 40000) loss: 1.157943
# (Time 373.47 sec; Iteration 38111 / 40000) loss: 0.970072
# (Time 373.56 sec; Iteration 38121 / 40000) loss: 1.081670
# (Time 373.66 sec; Iteration 38131 / 40000) loss: 1.132932
# (Time 373.76 sec; Iteration 38141 / 40000) loss: 1.157858
# (Time 373.86 sec; Iteration 38151 / 40000) loss: 1.033265
# (Time 373.95 sec; Iteration 38161 / 40000) loss: 1.002633
# (Time 374.04 sec; Iteration 38171 / 40000) loss: 1.319678
# (Time 374.13 sec; Iteration 38181 / 40000) loss: 1.171029
# (Time 374.22 sec; Iteration 38191 / 40000) loss: 1.093316
# (Time 374.31 sec; Iteration 38201 / 40000) loss: 1.073597
# (Time 374.40 sec; Iteration 38211 / 40000) loss: 0.981548
# (Time 374.50 sec; Iteration 38221 / 40000) loss: 1.000635
# (Time 374.59 sec; Iteration 38231 / 40000) loss: 1.058654
# (Time 374.69 sec; Iteration 38241 / 40000) loss: 1.012163
# (Time 374.78 sec; Iteration 38251 / 40000) loss: 1.034781
# (Time 374.87 sec; Iteration 38261 / 40000) loss: 1.045426
# (Time 374.96 sec; Iteration 38271 / 40000) loss: 0.980008
# (Time 375.05 sec; Iteration 38281 / 40000) loss: 1.112368
# (Time 375.14 sec; Iteration 38291 / 40000) loss: 1.066375
# (Time 375.23 sec; Iteration 38301 / 40000) loss: 0.951868
# (Time 375.32 sec; Iteration 38311 / 40000) loss: 0.870062
# (Time 375.41 sec; Iteration 38321 / 40000) loss: 1.116936
# (Time 375.50 sec; Iteration 38331 / 40000) loss: 1.050182
# (Time 375.60 sec; Iteration 38341 / 40000) loss: 1.108101
# (Time 375.69 sec; Iteration 38351 / 40000) loss: 0.998993
# (Time 375.79 sec; Iteration 38361 / 40000) loss: 1.008975
# (Time 375.87 sec; Iteration 38371 / 40000) loss: 1.032211
# (Time 375.97 sec; Iteration 38381 / 40000) loss: 1.010958
# (Time 376.06 sec; Iteration 38391 / 40000) loss: 0.969567
# (Epoch 96 / 100) train acc: 0.629000; val_acc: 0.530300
# (Time 376.42 sec; Iteration 38401 / 40000) loss: 0.966293
# (Time 376.51 sec; Iteration 38411 / 40000) loss: 0.996351
# (Time 376.60 sec; Iteration 38421 / 40000) loss: 1.216508
# (Time 376.69 sec; Iteration 38431 / 40000) loss: 0.999927
# (Time 376.78 sec; Iteration 38441 / 40000) loss: 1.255432
# (Time 376.86 sec; Iteration 38451 / 40000) loss: 1.207277
# (Time 376.96 sec; Iteration 38461 / 40000) loss: 0.830885
# (Time 377.05 sec; Iteration 38471 / 40000) loss: 1.019945
# (Time 377.16 sec; Iteration 38481 / 40000) loss: 1.122503
# (Time 377.25 sec; Iteration 38491 / 40000) loss: 1.074505
# (Time 377.34 sec; Iteration 38501 / 40000) loss: 0.983155
# (Time 377.43 sec; Iteration 38511 / 40000) loss: 1.129361
# (Time 377.52 sec; Iteration 38521 / 40000) loss: 0.925454
# (Time 377.61 sec; Iteration 38531 / 40000) loss: 1.007270
# (Time 377.70 sec; Iteration 38541 / 40000) loss: 1.008866
# (Time 377.79 sec; Iteration 38551 / 40000) loss: 1.018397
# (Time 377.88 sec; Iteration 38561 / 40000) loss: 1.151516
# (Time 377.97 sec; Iteration 38571 / 40000) loss: 1.053271
# (Time 378.06 sec; Iteration 38581 / 40000) loss: 1.012029
# (Time 378.15 sec; Iteration 38591 / 40000) loss: 0.826948
# (Time 378.24 sec; Iteration 38601 / 40000) loss: 1.007558
# (Time 378.33 sec; Iteration 38611 / 40000) loss: 1.224367
# (Time 378.42 sec; Iteration 38621 / 40000) loss: 0.965840
# (Time 378.51 sec; Iteration 38631 / 40000) loss: 1.166649
# (Time 378.61 sec; Iteration 38641 / 40000) loss: 0.998223
# (Time 378.69 sec; Iteration 38651 / 40000) loss: 1.098956
# (Time 378.79 sec; Iteration 38661 / 40000) loss: 0.954546
# (Time 378.88 sec; Iteration 38671 / 40000) loss: 0.785137
# (Time 378.96 sec; Iteration 38681 / 40000) loss: 0.857121
# (Time 379.05 sec; Iteration 38691 / 40000) loss: 0.989427
# (Time 379.15 sec; Iteration 38701 / 40000) loss: 0.930196
# (Time 379.24 sec; Iteration 38711 / 40000) loss: 1.113828
# (Time 379.33 sec; Iteration 38721 / 40000) loss: 1.087870
# (Time 379.42 sec; Iteration 38731 / 40000) loss: 1.054283
# (Time 379.51 sec; Iteration 38741 / 40000) loss: 1.179585
# (Time 379.60 sec; Iteration 38751 / 40000) loss: 0.875672
# (Time 379.69 sec; Iteration 38761 / 40000) loss: 0.823313
# (Time 379.78 sec; Iteration 38771 / 40000) loss: 0.946756
# (Time 379.87 sec; Iteration 38781 / 40000) loss: 1.092764
# (Time 379.96 sec; Iteration 38791 / 40000) loss: 1.107710
# (Epoch 97 / 100) train acc: 0.635000; val_acc: 0.527900
# (Time 380.31 sec; Iteration 38801 / 40000) loss: 1.010860
# (Time 380.40 sec; Iteration 38811 / 40000) loss: 1.118939
# (Time 380.49 sec; Iteration 38821 / 40000) loss: 1.104429
# (Time 380.59 sec; Iteration 38831 / 40000) loss: 0.853520
# (Time 380.68 sec; Iteration 38841 / 40000) loss: 0.940889
# (Time 380.77 sec; Iteration 38851 / 40000) loss: 1.000388
# (Time 380.86 sec; Iteration 38861 / 40000) loss: 0.954433
# (Time 380.95 sec; Iteration 38871 / 40000) loss: 1.038520
# (Time 381.04 sec; Iteration 38881 / 40000) loss: 1.026241
# (Time 381.13 sec; Iteration 38891 / 40000) loss: 1.073582
# (Time 381.22 sec; Iteration 38901 / 40000) loss: 1.011838
# (Time 381.32 sec; Iteration 38911 / 40000) loss: 0.939391
# (Time 381.42 sec; Iteration 38921 / 40000) loss: 1.003195
# (Time 381.51 sec; Iteration 38931 / 40000) loss: 0.917949
# (Time 381.61 sec; Iteration 38941 / 40000) loss: 0.876382
# (Time 381.70 sec; Iteration 38951 / 40000) loss: 1.045111
# (Time 381.79 sec; Iteration 38961 / 40000) loss: 0.870102
# (Time 381.89 sec; Iteration 38971 / 40000) loss: 1.073786
# (Time 381.98 sec; Iteration 38981 / 40000) loss: 1.110923
# (Time 382.07 sec; Iteration 38991 / 40000) loss: 1.198908
# (Time 382.16 sec; Iteration 39001 / 40000) loss: 0.918302
# (Time 382.25 sec; Iteration 39011 / 40000) loss: 1.191526
# (Time 382.34 sec; Iteration 39021 / 40000) loss: 1.083822
# (Time 382.44 sec; Iteration 39031 / 40000) loss: 1.133136
# (Time 382.53 sec; Iteration 39041 / 40000) loss: 1.144724
# (Time 382.62 sec; Iteration 39051 / 40000) loss: 1.109903
# (Time 382.71 sec; Iteration 39061 / 40000) loss: 1.047080
# (Time 382.81 sec; Iteration 39071 / 40000) loss: 0.943287
# (Time 382.90 sec; Iteration 39081 / 40000) loss: 0.953158
# (Time 382.99 sec; Iteration 39091 / 40000) loss: 0.996612
# (Time 383.08 sec; Iteration 39101 / 40000) loss: 0.990906
# (Time 383.17 sec; Iteration 39111 / 40000) loss: 1.014367
# (Time 383.27 sec; Iteration 39121 / 40000) loss: 1.099600
# (Time 383.36 sec; Iteration 39131 / 40000) loss: 0.904195
# (Time 383.45 sec; Iteration 39141 / 40000) loss: 1.121141
# (Time 383.55 sec; Iteration 39151 / 40000) loss: 1.011159
# (Time 383.64 sec; Iteration 39161 / 40000) loss: 1.049088
# (Time 383.74 sec; Iteration 39171 / 40000) loss: 1.045658
# (Time 383.83 sec; Iteration 39181 / 40000) loss: 0.950036
# (Time 383.92 sec; Iteration 39191 / 40000) loss: 0.776216
# (Epoch 98 / 100) train acc: 0.644000; val_acc: 0.526800
# (Time 384.28 sec; Iteration 39201 / 40000) loss: 1.041920
# (Time 384.38 sec; Iteration 39211 / 40000) loss: 1.075035
# (Time 384.49 sec; Iteration 39221 / 40000) loss: 1.273307
# (Time 384.59 sec; Iteration 39231 / 40000) loss: 0.992796
# (Time 384.68 sec; Iteration 39241 / 40000) loss: 1.113373
# (Time 384.77 sec; Iteration 39251 / 40000) loss: 1.125020
# (Time 384.86 sec; Iteration 39261 / 40000) loss: 0.899438
# (Time 384.95 sec; Iteration 39271 / 40000) loss: 0.942176
# (Time 385.04 sec; Iteration 39281 / 40000) loss: 1.107469
# (Time 385.13 sec; Iteration 39291 / 40000) loss: 1.086809
# (Time 385.22 sec; Iteration 39301 / 40000) loss: 1.132530
# (Time 385.31 sec; Iteration 39311 / 40000) loss: 1.203831
# (Time 385.41 sec; Iteration 39321 / 40000) loss: 1.032436
# (Time 385.50 sec; Iteration 39331 / 40000) loss: 1.205590
# (Time 385.59 sec; Iteration 39341 / 40000) loss: 1.046642
# (Time 385.69 sec; Iteration 39351 / 40000) loss: 0.994205
# (Time 385.79 sec; Iteration 39361 / 40000) loss: 1.140740
# (Time 385.88 sec; Iteration 39371 / 40000) loss: 1.009660
# (Time 385.98 sec; Iteration 39381 / 40000) loss: 1.025570
# (Time 386.07 sec; Iteration 39391 / 40000) loss: 1.139630
# (Time 386.16 sec; Iteration 39401 / 40000) loss: 0.973195
# (Time 386.25 sec; Iteration 39411 / 40000) loss: 0.955283
# (Time 386.35 sec; Iteration 39421 / 40000) loss: 1.070924
# (Time 386.44 sec; Iteration 39431 / 40000) loss: 0.977694
# (Time 386.53 sec; Iteration 39441 / 40000) loss: 0.986594
# (Time 386.62 sec; Iteration 39451 / 40000) loss: 1.212082
# (Time 386.71 sec; Iteration 39461 / 40000) loss: 1.115383
# (Time 386.80 sec; Iteration 39471 / 40000) loss: 0.902290
# (Time 386.89 sec; Iteration 39481 / 40000) loss: 0.953269
# (Time 386.98 sec; Iteration 39491 / 40000) loss: 1.018514
# (Time 387.07 sec; Iteration 39501 / 40000) loss: 1.026421
# (Time 387.16 sec; Iteration 39511 / 40000) loss: 1.124516
# (Time 387.25 sec; Iteration 39521 / 40000) loss: 1.069644
# (Time 387.34 sec; Iteration 39531 / 40000) loss: 1.001717
# (Time 387.43 sec; Iteration 39541 / 40000) loss: 1.108729
# (Time 387.52 sec; Iteration 39551 / 40000) loss: 1.092699
# (Time 387.63 sec; Iteration 39561 / 40000) loss: 1.016232
# (Time 387.72 sec; Iteration 39571 / 40000) loss: 1.085195
# (Time 387.82 sec; Iteration 39581 / 40000) loss: 0.941405
# (Time 387.91 sec; Iteration 39591 / 40000) loss: 0.894649
# (Epoch 99 / 100) train acc: 0.663000; val_acc: 0.526800
# (Time 388.26 sec; Iteration 39601 / 40000) loss: 1.094436
# (Time 388.35 sec; Iteration 39611 / 40000) loss: 0.876104
# (Time 388.44 sec; Iteration 39621 / 40000) loss: 1.064608
# (Time 388.53 sec; Iteration 39631 / 40000) loss: 0.927338
# (Time 388.63 sec; Iteration 39641 / 40000) loss: 1.070810
# (Time 388.72 sec; Iteration 39651 / 40000) loss: 0.951811
# (Time 388.81 sec; Iteration 39661 / 40000) loss: 0.920681
# (Time 388.90 sec; Iteration 39671 / 40000) loss: 1.123485
# (Time 388.99 sec; Iteration 39681 / 40000) loss: 0.951470
# (Time 389.08 sec; Iteration 39691 / 40000) loss: 0.923696
# (Time 389.18 sec; Iteration 39701 / 40000) loss: 1.107921
# (Time 389.27 sec; Iteration 39711 / 40000) loss: 1.038513
# (Time 389.37 sec; Iteration 39721 / 40000) loss: 0.870454
# (Time 389.46 sec; Iteration 39731 / 40000) loss: 1.044531
# (Time 389.55 sec; Iteration 39741 / 40000) loss: 1.072285
# (Time 389.65 sec; Iteration 39751 / 40000) loss: 0.896904
# (Time 389.74 sec; Iteration 39761 / 40000) loss: 1.182030
# (Time 389.83 sec; Iteration 39771 / 40000) loss: 0.970604
# (Time 389.92 sec; Iteration 39781 / 40000) loss: 1.084087
# (Time 390.01 sec; Iteration 39791 / 40000) loss: 0.963415
# (Time 390.10 sec; Iteration 39801 / 40000) loss: 0.942814
# (Time 390.19 sec; Iteration 39811 / 40000) loss: 0.963651
# (Time 390.28 sec; Iteration 39821 / 40000) loss: 1.078174
# (Time 390.37 sec; Iteration 39831 / 40000) loss: 0.794924
# (Time 390.46 sec; Iteration 39841 / 40000) loss: 0.937942
# (Time 390.55 sec; Iteration 39851 / 40000) loss: 1.092576
# (Time 390.64 sec; Iteration 39861 / 40000) loss: 0.916812
# (Time 390.73 sec; Iteration 39871 / 40000) loss: 1.125261
# (Time 390.83 sec; Iteration 39881 / 40000) loss: 0.908803
# (Time 390.92 sec; Iteration 39891 / 40000) loss: 0.976507
# (Time 391.01 sec; Iteration 39901 / 40000) loss: 1.004840
# (Time 391.10 sec; Iteration 39911 / 40000) loss: 1.079181
# (Time 391.20 sec; Iteration 39921 / 40000) loss: 1.191446
# (Time 391.29 sec; Iteration 39931 / 40000) loss: 1.151226
# (Time 391.39 sec; Iteration 39941 / 40000) loss: 1.191302
# (Time 391.48 sec; Iteration 39951 / 40000) loss: 1.116746
# (Time 391.58 sec; Iteration 39961 / 40000) loss: 0.861544
# (Time 391.67 sec; Iteration 39971 / 40000) loss: 0.873840
# (Time 391.76 sec; Iteration 39981 / 40000) loss: 1.075207
# (Time 391.85 sec; Iteration 39991 / 40000) loss: 1.195557
# (Epoch 100 / 100) train acc: 0.641000; val_acc: 0.531000

# %%
# Run this cell to visualize training loss and train / val accuracy
plt.subplot(2, 1, 1)
plt.title('Training loss')
plt.plot(solver.loss_history, 'o')
plt.xlabel('Iteration')

plt.subplot(2, 1, 2)
plt.title('Accuracy')
plt.plot(solver.train_acc_history, '-o', label='train')
plt.plot(solver.val_acc_history, '-o', label='val')
plt.plot([0.5] * len(solver.val_acc_history), 'k--')
plt.xlabel('Epoch')
plt.legend(loc='lower right')
plt.gcf().set_size_inches(15, 12)
plt.show()

# %% [markdown]
# If you're happy with the model's perfromance, run the following cell to save it.
#
# We will also reload the model and run it on validation to verify it's the right weights.

# %%
import os
path = os.path.join('/', 'best_two_layer_net.pth')
solver.model.save(path)

# Create a new instance
from fully_connected_networks import create_solver_instance
reset_seed(0)

solver = create_solver_instance(data_dict=data_dict, dtype=torch.float64, device='cuda')

# Load model
solver.model.load(path, dtype=torch.float64, device='cuda')

# Evaluate on validation set
accuracy = solver.check_accuracy(solver.X_val, solver.y_val)
print(f"Saved model's accuracy on validation is {accuracy}")
# Out:
# Saved in /best_two_layer_net.pth
# load checkpoint file: /best_two_layer_net.pth
# d:\Code\eecs\A3\fully_connected_networks.py:231: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(path, map_location='cpu')
# Saved model's accuracy on validation is 0.5309999585151672

# %% [markdown]
# # Multilayer network
# Next you will implement a fully-connected network with an arbitrary number of hidden layers.
#
# Read through the `FullyConnectedNet` class in `fully_connected_networks.py`. Implement the initialization, the forward pass, and the backward pass. For the moment don't worry about implementing dropout; we will add this feature soon.

# %% [markdown]
# ## Initial loss and gradient check
#
# As a sanity check, run the following to check the initial loss and to gradient check the network both with and without regularization. Do the initial losses seem reasonable?
#
# For gradient checking, you should expect to see errors less than `1e-6`, except for the check on `W1` and `W2` with `reg=0` where your errors should be less than `1e-5`.

# %%
from fully_connected_networks import FullyConnectedNet

reset_seed(0)
N, D, H1, H2, C = 2, 15, 20, 30, 10
X = torch.randn(N, D, dtype=torch.float64, device='cuda')
y = torch.randint(C, size=(N,), dtype=torch.int64, device='cuda')

for reg in [0, 3.14]:
  print('Running check with reg = ', reg)
  model = FullyConnectedNet(
        [H1, H2], 
        input_dim=D,
        num_classes=C,
        reg=reg,
        weight_scale=5e-2, 
        dtype=torch.float64, 
        device='cuda'
  )

  loss, grads = model.loss(X, y)
  print('Initial loss: ', loss.item())

  for name in sorted(grads):
    f = lambda _: model.loss(X, y)[0]
    grad_num = eecs598.grad.compute_numeric_gradient(f, model.params[name])
    print('%s relative error: %.2e' % (name, eecs598.grad.rel_error(grad_num, grads[name])))
# Out:
# Running check with reg =  0
# Initial loss:  2.3053575717037686
# W1 relative error: 6.06e-08
# W2 relative error: 1.02e-07
# W3 relative error: 5.89e-08
# b1 relative error: 1.28e-07
# b2 relative error: 2.05e-08
# b3 relative error: 3.41e-09
# Running check with reg =  3.14
# Initial loss:  12.278358041494133
# W1 relative error: 9.42e-09
# W2 relative error: 8.70e-09
# W3 relative error: 8.46e-09
# b1 relative error: 2.87e-07
# b2 relative error: 6.57e-08
# b3 relative error: 6.23e-09

# %% [markdown]
# As another sanity check, make sure you can overfit a small dataset of 50 images. First we will try a three-layer network with 100 units in each hidden layer. In the following cell, tweak the **learning rate** and **weight initialization scale** to overfit and achieve 100% training accuracy within 20 epochs.

# %%
from fully_connected_networks import FullyConnectedNet, get_three_layer_network_params

# TODO: Use a three-layer Net to overfit 50 training examples by 
# tweaking just the learning rate and initialization scale.
reset_seed(0)

num_train = 50
small_data = {
  'X_train': data_dict['X_train'][:num_train],
  'y_train': data_dict['y_train'][:num_train],
  'X_val': data_dict['X_val'],
  'y_val': data_dict['y_val'],
}

# Update parameters in get_three_layer_network_params
weight_scale, learning_rate = get_three_layer_network_params()

model = FullyConnectedNet([100, 100],
              weight_scale=weight_scale, dtype=torch.float32, device='cuda')
solver = Solver(model, small_data,
                print_every=10, num_epochs=20, batch_size=25,
                optim_config={
                  'learning_rate': learning_rate,
                },
                device='cuda',
         )
solver.train()

plt.plot(solver.loss_history, 'o')
plt.title('Training loss history')
plt.xlabel('Iteration')
plt.ylabel('Training loss')
plt.show()
# Out:
# (Time 0.00 sec; Iteration 1 / 40) loss: 2.564451
# (Epoch 0 / 20) train acc: 0.220000; val_acc: 0.105900
# (Epoch 1 / 20) train acc: 0.340000; val_acc: 0.118400
# (Epoch 2 / 20) train acc: 0.480000; val_acc: 0.128200
# (Epoch 3 / 20) train acc: 0.480000; val_acc: 0.132700
# (Epoch 4 / 20) train acc: 0.740000; val_acc: 0.164400
# (Epoch 5 / 20) train acc: 0.840000; val_acc: 0.156100
# (Time 0.48 sec; Iteration 11 / 40) loss: 1.105345
# (Epoch 6 / 20) train acc: 0.900000; val_acc: 0.159100
# (Epoch 7 / 20) train acc: 0.940000; val_acc: 0.168700
# (Epoch 8 / 20) train acc: 0.940000; val_acc: 0.173600
# (Epoch 9 / 20) train acc: 0.900000; val_acc: 0.175600
# (Epoch 10 / 20) train acc: 0.960000; val_acc: 0.176000
# (Time 0.72 sec; Iteration 21 / 40) loss: 0.543195
# (Epoch 11 / 20) train acc: 1.000000; val_acc: 0.176700
# (Epoch 12 / 20) train acc: 1.000000; val_acc: 0.184500
# (Epoch 13 / 20) train acc: 1.000000; val_acc: 0.178800
# (Epoch 14 / 20) train acc: 0.980000; val_acc: 0.180100
# (Epoch 15 / 20) train acc: 1.000000; val_acc: 0.180500
# (Time 0.96 sec; Iteration 31 / 40) loss: 0.303252
# (Epoch 16 / 20) train acc: 1.000000; val_acc: 0.182500
# (Epoch 17 / 20) train acc: 1.000000; val_acc: 0.184800
# (Epoch 18 / 20) train acc: 1.000000; val_acc: 0.187100
# (Epoch 19 / 20) train acc: 1.000000; val_acc: 0.187800
# (Epoch 20 / 20) train acc: 1.000000; val_acc: 0.187900

# %% [markdown]
# Now try to use a five-layer network with 100 units on each layer to overfit 50 training examples. Again, you will have to adjust the learning rate and weight initialization scale, but you should be able to achieve 100% training accuracy within 20 epochs.

# %%
from fully_connected_networks import FullyConnectedNet, get_five_layer_network_params

# TODO: Use a five-layer Net to overfit 50 training examples by 
# tweaking just the learning rate and initialization scale.
reset_seed(0)

num_train = 50
small_data = {
  'X_train': data_dict['X_train'][:num_train],
  'y_train': data_dict['y_train'][:num_train],
  'X_val': data_dict['X_val'],
  'y_val': data_dict['y_val'],
}


# Update parameters in get_three_layer_network_params
weight_scale, learning_rate = get_five_layer_network_params()

# Run models and solver with parameters
model = FullyConnectedNet([100, 100, 100, 100],
                weight_scale=weight_scale, dtype=torch.float32, device='cuda')
solver = Solver(model, small_data,
                print_every=10, num_epochs=20, batch_size=25,
                optim_config={
                  'learning_rate': learning_rate,
                },
                device='cuda',
         )
# Turn off keep_best_params to allow final weights to be saved, instead of best weights on validation set.
solver.train(return_best_params=False)

plt.plot(solver.loss_history, 'o')
plt.title('Training loss history')
plt.xlabel('Iteration')
plt.ylabel('Training loss')
plt.show()
# Out:
# (Time 0.01 sec; Iteration 1 / 40) loss: 2.307012
# (Epoch 0 / 20) train acc: 0.220000; val_acc: 0.107200
# (Epoch 1 / 20) train acc: 0.280000; val_acc: 0.114500
# (Epoch 2 / 20) train acc: 0.440000; val_acc: 0.114000
# (Epoch 3 / 20) train acc: 0.500000; val_acc: 0.118100
# (Epoch 4 / 20) train acc: 0.600000; val_acc: 0.140400
# (Epoch 5 / 20) train acc: 0.780000; val_acc: 0.153500
# (Time 0.57 sec; Iteration 11 / 40) loss: 1.127662
# (Epoch 6 / 20) train acc: 0.760000; val_acc: 0.150200
# (Epoch 7 / 20) train acc: 0.600000; val_acc: 0.158300
# (Epoch 8 / 20) train acc: 0.820000; val_acc: 0.170700
# (Epoch 9 / 20) train acc: 0.880000; val_acc: 0.173400
# (Epoch 10 / 20) train acc: 0.900000; val_acc: 0.153100
# (Time 0.98 sec; Iteration 21 / 40) loss: 0.453191
# (Epoch 11 / 20) train acc: 0.940000; val_acc: 0.166300
# (Epoch 12 / 20) train acc: 0.980000; val_acc: 0.169300
# (Epoch 13 / 20) train acc: 0.960000; val_acc: 0.177700
# (Epoch 14 / 20) train acc: 0.960000; val_acc: 0.171200
# (Epoch 15 / 20) train acc: 0.940000; val_acc: 0.180500
# (Time 1.38 sec; Iteration 31 / 40) loss: 0.163125
# (Epoch 16 / 20) train acc: 1.000000; val_acc: 0.178600
# (Epoch 17 / 20) train acc: 1.000000; val_acc: 0.184200
# (Epoch 18 / 20) train acc: 0.980000; val_acc: 0.187800
# (Epoch 19 / 20) train acc: 0.980000; val_acc: 0.178200
# (Epoch 20 / 20) train acc: 1.000000; val_acc: 0.187800

# %% [markdown]
# If you're satisfied with your model's performance, save the overfit model. Just a sanity check, we evaluate it one the training set again to verify that the saved weights have the correct performance.

# %%
# Set path 
import os
path = os.path.join('/', 'best_overfit_five_layer_net.pth')
solver.model.save(path)


# Create a new instance  -- Note that hidden dims being different doesn't matter here.
model = FullyConnectedNet(hidden_dims=[100, ], dtype=torch.float32, device='cuda')
solver = Solver(model, small_data,
                print_every=10, num_epochs=20, batch_size=25,
                optim_config={
                  'learning_rate': learning_rate,
                },
                device='cuda',
         )


# Load model
solver.model.load(path, dtype=torch.float32, device='cuda')

# Evaluate on validation set
accuracy = solver.check_accuracy(solver.X_train, solver.y_train)
print(f"Saved model's accuracy on small train is {accuracy}")
# Out:
# Saved in /best_overfit_five_layer_net.pth
# load checkpoint file: /best_overfit_five_layer_net.pth
# Saved model's accuracy on small train is 1.0
# d:\Code\eecs\A3\fully_connected_networks.py:406: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(path, map_location='cpu')

# %% [markdown]
# # Update rules
# So far we have used vanilla stochastic gradient descent (SGD) as our update rule. More sophisticated update rules can make it easier to train deep networks. We will implement a few of the most commonly used update rules and compare them to vanilla SGD.

# %% [markdown]
# ## SGD+Momentum
# Stochastic gradient descent with momentum is a widely used update rule that tends to make deep networks converge faster than vanilla stochastic gradient descent. See the Momentum Update section at http://cs231n.github.io/neural-networks-3/#sgd for more information.
#
# We will implement various first-order update rules that are commonly used
# for training neural networks. Each update rule accepts current weights and the
# gradient of the loss with respect to those weights and produces the next set of
# weights. Each update rule has the same interface:
# ```python
# def update(w, dw, config=None):
# Inputs:
#   - w: A tensor giving the current weights.
#   - dw: A tensor of the same shape as w giving the gradient of the
#     loss with respect to w.
#   - config: A dictionary containing hyperparameter values such as learning
#     rate, momentum, etc. If the update rule requires caching values over many
#     iterations, then config will also hold these cached values.
# Returns:
#   - next_w: The next point after the update.
#   - config: The config dictionary to be passed to the next iteration of the
#     update rule.
# NOTE: For most update rules, the default learning rate will probably not
# perform well; however the default values of the other hyperparameters should
# work well for a variety of different problems.
# For efficiency, update rules may perform in-place updates, mutating w and
# setting next_w equal to w.
# ```
# We provide the implementation of the SGD update rule for your reference in `fully_connected_networks.py`
#
# Now **implement** the SGD+Momentum update rule using the same interface. Run the following to check your implementation of SGD+Momentum. You should see errors less than `1e-7`.

# %%
from fully_connected_networks import sgd_momentum

reset_seed(0)

N, D = 4, 5
w = torch.linspace(-0.4, 0.6, steps=N*D, dtype=torch.float64, device='cuda').reshape(N, D)
dw = torch.linspace(-0.6, 0.4, steps=N*D, dtype=torch.float64, device='cuda').reshape(N, D)
v = torch.linspace(0.6, 0.9, steps=N*D, dtype=torch.float64, device='cuda').reshape(N, D)

config = {'learning_rate': 1e-3, 'velocity': v}
next_w, _ = sgd_momentum(w, dw, config=config)

expected_next_w = torch.tensor([
  [ 0.1406,      0.20738947,  0.27417895,  0.34096842,  0.40775789],
  [ 0.47454737,  0.54133684,  0.60812632,  0.67491579,  0.74170526],
  [ 0.80849474,  0.87528421,  0.94207368,  1.00886316,  1.07565263],
  [ 1.14244211,  1.20923158,  1.27602105,  1.34281053,  1.4096    ]],
   dtype=torch.float64, device='cuda')
expected_velocity = torch.tensor([
  [ 0.5406,      0.55475789,  0.56891579, 0.58307368,  0.59723158],
  [ 0.61138947,  0.62554737,  0.63970526,  0.65386316,  0.66802105],
  [ 0.68217895,  0.69633684,  0.71049474,  0.72465263,  0.73881053],
  [ 0.75296842,  0.76712632,  0.78128421,  0.79544211,  0.8096    ]],
   dtype=torch.float64, device='cuda')

# Should see relative errors around e-8 or less
print('next_w error: ', eecs598.grad.rel_error(next_w, expected_next_w))
print('velocity error: ', eecs598.grad.rel_error(expected_velocity, config['velocity']))
# Out:
# next_w error:  1.6802078709310813e-09
# velocity error:  2.9254212825785614e-09

# %% [markdown]
# Once you have done so, run the following to train a six-layer network with both SGD and SGD+momentum. You should see the SGD+momentum update rule converge faster.

# %%
from fully_connected_networks import FullyConnectedNet, sgd, sgd_momentum

# TODO: Use a three-layer Net to overfit 50 training examples by 
# tweaking just the learning rate and initialization scale.
reset_seed(0)

num_train = 4000
small_data = {
  'X_train': data_dict['X_train'][:num_train],
  'y_train': data_dict['y_train'][:num_train],
  'X_val': data_dict['X_val'],
  'y_val': data_dict['y_val'],
}

solvers = {}

for update_rule_name, update_rule_fn in [('sgd', sgd), ('sgd_momentum', sgd_momentum)]:
  print('running with ', update_rule_name)
  model = FullyConnectedNet([100, 100, 100, 100, 100], weight_scale=5e-2,
                            dtype=torch.float32, device='cuda')

  solver = Solver(model, small_data,
                  num_epochs=5, batch_size=100,
                  update_rule=update_rule_fn,
                  optim_config={
                    'learning_rate': 5e-2,
                  },
                  print_every=1000,
                  verbose=True,
                  device='cuda')
  solvers[update_rule_name] = solver
  solver.train()
  print()
  
plt.subplot(3, 1, 1)
plt.title('Training loss')
plt.xlabel('Iteration')
for update_rule, solver in solvers.items():
  plt.plot(solver.loss_history, 'o', label="loss_%s" % update_rule)
plt.legend(loc='lower center', ncol=4)
  
plt.subplot(3, 1, 2)
plt.title('Training accuracy')
plt.xlabel('Epoch')
for update_rule, solver in solvers.items():
  plt.plot(solver.train_acc_history, '-o', label="train_acc_%s" % update_rule)
plt.legend(loc='lower center', ncol=4)

  
plt.subplot(3, 1, 3)
plt.title('Validation accuracy')
plt.xlabel('Epoch')
for update_rule, solver in solvers.items():
  plt.plot(solver.val_acc_history, '-o', label="val_acc_%s" % update_rule)
plt.legend(loc='lower center', ncol=4)

plt.gcf().set_size_inches(10, 20)
plt.show()
# Out:
# running with  sgd
# (Time 0.01 sec; Iteration 1 / 200) loss: 2.302109
# (Epoch 0 / 5) train acc: 0.108000; val_acc: 0.098000
# (Epoch 1 / 5) train acc: 0.109000; val_acc: 0.095600
# (Epoch 2 / 5) train acc: 0.105000; val_acc: 0.095900
# (Epoch 3 / 5) train acc: 0.107000; val_acc: 0.092500
# (Epoch 4 / 5) train acc: 0.100000; val_acc: 0.090700
# (Epoch 5 / 5) train acc: 0.112000; val_acc: 0.097000
#
# running with  sgd_momentum
# (Time 0.01 sec; Iteration 1 / 200) loss: 2.302904
# (Epoch 0 / 5) train acc: 0.108000; val_acc: 0.108800
# (Epoch 1 / 5) train acc: 0.105000; val_acc: 0.095700
# (Epoch 2 / 5) train acc: 0.154000; val_acc: 0.154600
# (Epoch 3 / 5) train acc: 0.177000; val_acc: 0.174800
# (Epoch 4 / 5) train acc: 0.262000; val_acc: 0.217100
# (Epoch 5 / 5) train acc: 0.289000; val_acc: 0.246700

# %% [markdown]
# ## RMSProp
# RMSProp [1] is an update rule that set per-parameter learning rates by using a running average of the second moments of gradients.
#
# **Implement** the RMSProp update rule in the `rmsprop` function in `fully_connected_networks.py`. Run the following to test your RMSProp implementation. You should see errors less than `1e-6`.
#
# [1] Tijmen Tieleman and Geoffrey Hinton. "Lecture 6.5-rmsprop: Divide the gradient by a running average of its recent magnitude." COURSERA: Neural Networks for Machine Learning 4 (2012).

# %%
# Test RMSProp implementation
from fully_connected_networks import rmsprop

reset_seed(0)

N, D = 4, 5
w = torch.linspace(-0.4, 0.6, steps=N*D, dtype=torch.float64, device='cuda').reshape(N, D)
dw = torch.linspace(-0.6, 0.4, steps=N*D, dtype=torch.float64, device='cuda').reshape(N, D)
cache = torch.linspace(0.6, 0.9, steps=N*D, dtype=torch.float64, device='cuda').reshape(N, D)

config = {'learning_rate': 1e-2, 'cache': cache}
next_w, _ = rmsprop(w, dw, config=config)

expected_next_w = torch.tensor([
  [-0.39223849, -0.34037513, -0.28849239, -0.23659121, -0.18467247],
  [-0.132737,   -0.08078555, -0.02881884,  0.02316247,  0.07515774],
  [ 0.12716641,  0.17918792,  0.23122175,  0.28326742,  0.33532447],
  [ 0.38739248,  0.43947102,  0.49155973,  0.54365823,  0.59576619]],
   dtype=torch.float64, device='cuda')
expected_cache = torch.tensor([
  [ 0.5976,      0.6126277,   0.6277108,   0.64284931,  0.65804321],
  [ 0.67329252,  0.68859723,  0.70395734,  0.71937285,  0.73484377],
  [ 0.75037008,  0.7659518,   0.78158892,  0.79728144,  0.81302936],
  [ 0.82883269,  0.84469141,  0.86060554,  0.87657507,  0.8926    ]],
   dtype=torch.float64, device='cuda')

print('next_w error: ', eecs598.grad.rel_error(expected_next_w, next_w))
print('cache error: ', eecs598.grad.rel_error(expected_cache, config['cache']))
# Out:
# next_w error:  4.064797880829826e-09
# cache error:  1.8620321382570356e-09

# %% [markdown]
# ## Adam
# Adam [2] extends RMSprop with a first-order gradient cache similar to momentum, and a bias correction mechanism to prevent large steps at the start of optimization. Adam is one of the most commonly used update rules used in practice for training deep neural networks.
#
# Implement the Adam update rule in the `adam` function in `fully_connected_networks.py`. Run the following to test your Adam implementation. You should see error less than `1e-6` for `next_w`, and errors less than `1e-8` for `v` and `m`:
#
#
#
# **NOTE:** Please implement the _complete_ Adam update rule (with the bias correction mechanism), not the first simplified version mentioned in the course notes.
#
# [2] Diederik Kingma and Jimmy Ba, "Adam: A Method for Stochastic Optimization", ICLR 2015.

# %%
# Test Adam implementation
from fully_connected_networks import adam

reset_seed(0)

N, D = 4, 5
w = torch.linspace(-0.4, 0.6, steps=N*D, dtype=torch.float64, device='cuda').reshape(N, D)
dw = torch.linspace(-0.6, 0.4, steps=N*D, dtype=torch.float64, device='cuda').reshape(N, D)
m = torch.linspace(0.6, 0.9, steps=N*D, dtype=torch.float64, device='cuda').reshape(N, D)
v = torch.linspace(0.7, 0.5, steps=N*D, dtype=torch.float64, device='cuda').reshape(N, D)

config = {'learning_rate': 1e-2, 'm': m, 'v': v, 't': 5}
next_w, _ = adam(w, dw, config=config)

expected_next_w = torch.tensor([
  [-0.40094747, -0.34836187, -0.29577703, -0.24319299, -0.19060977],
  [-0.1380274,  -0.08544591, -0.03286534,  0.01971428,  0.0722929],
  [ 0.1248705,   0.17744702,  0.23002243,  0.28259667,  0.33516969],
  [ 0.38774145,  0.44031188,  0.49288093,  0.54544852,  0.59801459]],
   dtype=torch.float64, device='cuda')
expected_v = torch.tensor([
  [ 0.69966,     0.68908382,  0.67851319,  0.66794809,  0.65738853,],
  [ 0.64683452,  0.63628604,  0.6257431,   0.61520571,  0.60467385,],
  [ 0.59414753,  0.58362676,  0.57311152,  0.56260183,  0.55209767,],
  [ 0.54159906,  0.53110598,  0.52061845,  0.51013645,  0.49966,   ]],
   dtype=torch.float64, device='cuda')
expected_m = torch.tensor([
  [ 0.48,        0.49947368,  0.51894737,  0.53842105,  0.55789474],
  [ 0.57736842,  0.59684211,  0.61631579,  0.63578947,  0.65526316],
  [ 0.67473684,  0.69421053,  0.71368421,  0.73315789,  0.75263158],
  [ 0.77210526,  0.79157895,  0.81105263,  0.83052632,  0.85      ]],
   dtype=torch.float64, device='cuda')

# You should see relative errors around e-7 or less
print('next_w error: ', eecs598.grad.rel_error(expected_next_w, next_w))
print('v error: ', eecs598.grad.rel_error(expected_v, config['v']))
print('m error: ', eecs598.grad.rel_error(expected_m, config['m']))
# Out:
# next_w error:  3.756728297598868e-09
# v error:  3.4048987160545265e-09
# m error:  2.786377729853651e-09

# %% [markdown]
# Once you have debugged your RMSProp and Adam implementations, run the following to train a pair of deep networks using these new update rules:

# %%
# Test Adam implementation
from fully_connected_networks import adam, rmsprop, FullyConnectedNet

for update_rule_name, update_rule_fn, learning_rate in [('adam', adam, 1e-3), ('rmsprop', rmsprop, 1e-4)]:
  print('running with ', update_rule)
  model = FullyConnectedNet([100, 100, 100, 100, 100], weight_scale=5e-2, device='cuda')

  solver = Solver(model, small_data,
                  num_epochs=5, batch_size=100,
                  update_rule=update_rule_fn,
                  optim_config={
                    'learning_rate': learning_rate
                  },
                  print_every=1000,
                  verbose=True, device='cuda')
  solvers[update_rule_name] = solver
  solver.train()
  print()

plt.subplot(3, 1, 1)
plt.title('Training loss')
plt.xlabel('Iteration')
for update_rule, solver in list(solvers.items()):
  plt.plot(solver.loss_history, 'o', label=update_rule)
plt.legend(loc='lower center', ncol=4)
  
plt.subplot(3, 1, 2)
plt.title('Training accuracy')
plt.xlabel('Epoch')
for update_rule, solver in list(solvers.items()):
  plt.plot(solver.train_acc_history, '-o', label=update_rule)
plt.legend(loc='lower center', ncol=4)

plt.subplot(3, 1, 3)
plt.title('Validation accuracy')
plt.xlabel('Epoch')
for update_rule, solver in list(solvers.items()):
  plt.plot(solver.val_acc_history, '-o', label=update_rule)
plt.legend(loc='lower center', ncol=4)

plt.gcf().set_size_inches(10, 20)
plt.show()
# Out:
# running with  sgd_momentum
# (Time 0.01 sec; Iteration 1 / 200) loss: 2.302109
# (Epoch 0 / 5) train acc: 0.107000; val_acc: 0.100100
# (Epoch 1 / 5) train acc: 0.270000; val_acc: 0.243300
# (Epoch 2 / 5) train acc: 0.297000; val_acc: 0.281200
# (Epoch 3 / 5) train acc: 0.353000; val_acc: 0.321400
# (Epoch 4 / 5) train acc: 0.393000; val_acc: 0.319500
# (Epoch 5 / 5) train acc: 0.445000; val_acc: 0.357400
#
# running with  sgd_momentum
# (Time 0.01 sec; Iteration 1 / 200) loss: 2.302904
# (Epoch 0 / 5) train acc: 0.145000; val_acc: 0.152900
# (Epoch 1 / 5) train acc: 0.231000; val_acc: 0.193600
# (Epoch 2 / 5) train acc: 0.266000; val_acc: 0.233800
# (Epoch 3 / 5) train acc: 0.262000; val_acc: 0.246400
# (Epoch 4 / 5) train acc: 0.325000; val_acc: 0.261400
# (Epoch 5 / 5) train acc: 0.300000; val_acc: 0.284000

# %% [markdown]
# # Dropout
# Dropout [1] is a technique for regularizing neural networks by randomly setting some output activations to zero during the forward pass. In this exercise you will implement a dropout layer and modify your fully-connected network to optionally use dropout.
#
# [1] [Geoffrey E. Hinton et al, "Improving neural networks by preventing co-adaptation of feature detectors", arXiv 2012](https://arxiv.org/abs/1207.0580)

# %% [markdown]
# ## Dropout: forward
# **Implement** the forward pass for dropout in `fully_connected_networks.py`. Since dropout behaves differently during training and testing, make sure to implement the operation for both modes.
#
# Run the following to test your dropout implementation. The mean of the output should be approximately the same during training and testing. During training the number of outputs set to zero should be approximately equal to the drop probability `p`, and during testing no outputs should be set to zero.

# %%
from fully_connected_networks import Dropout

reset_seed(0)
x = torch.randn(500, 500, dtype=torch.float64, device='cuda') + 10

for p in [0.25, 0.4, 0.7]:
  out, _ = Dropout.forward(x, {'mode': 'train', 'p': p})
  out_test, _ = Dropout.forward(x, {'mode': 'test', 'p': p})

  print('Running tests with p = ', p)
  print('Mean of input: ', x.mean().item())
  print('Mean of train-time output: ', out.mean().item())
  print('Mean of test-time output: ', out_test.mean().item())
  print('Fraction of train-time output set to zero: ', (out == 0).type(torch.float32).mean().item())
  print('Fraction of test-time output set to zero: ', (out_test == 0).type(torch.float32).mean().item())
  print()
# Out:
# Running tests with p =  0.25
# Mean of input:  10.002638910253042
# Mean of train-time output:  10.001717217796816
# Mean of test-time output:  10.002638910253042
# Fraction of train-time output set to zero:  0.25008800625801086
# Fraction of test-time output set to zero:  0.0
#
# Running tests with p =  0.4
# Mean of input:  10.002638910253042
# Mean of train-time output:  9.975941569199472
# Mean of test-time output:  10.002638910253042
# Fraction of train-time output set to zero:  0.4014720022678375
# Fraction of test-time output set to zero:  0.0
#
# Running tests with p =  0.7
# Mean of input:  10.002638910253042
# Mean of train-time output:  10.016112877384508
# Mean of test-time output:  10.002638910253042
# Fraction of train-time output set to zero:  0.699679970741272
# Fraction of test-time output set to zero:  0.0

# %% [markdown]
# ## Dropout: backward
# Implement the backward pass for dropout. After doing so, run the following cell to numerically gradient-check your implementation.

# %%
from fully_connected_networks import Dropout

reset_seed(0)
x = torch.randn(10, 10, dtype=torch.float64, device='cuda') + 10
dout = torch.randn_like(x)

dropout_param = {'mode': 'train', 'p': 0.2, 'seed': 0}
out, cache = Dropout.forward(x, dropout_param)
dx = Dropout.backward(dout, cache)
dx_num = eecs598.grad.compute_numeric_gradient(lambda xx: Dropout.forward(xx, dropout_param)[0], x, dout)

# Error should be around e-10 or less
print('dx relative error: ', eecs598.grad.rel_error(dx, dx_num))
# Out:
# dx relative error:  3.914942325636866e-09

# %% [markdown]
# # Fully-connected nets with dropout
# Modify [your implementation](#scrollTo=7p-goSyucyZH) of `FullyConnectedNet` to use dropout. Specifically, if the constructor of the network receives a value that is not 0 for the `dropout` parameter, then the net should add a dropout layer immediately after every ReLU nonlinearity.
#
# After doing so, run the following to numerically gradient-check your implementation. You should see errors less than `1e-5`, and different dropout rates should result different error values.

# %%
from fully_connected_networks import FullyConnectedNet

reset_seed(0)

N, D, H1, H2, C = 2, 15, 20, 30, 10
X = torch.randn(N, D, dtype=torch.float64, device='cuda')
y = torch.randint(C, size=(N,), dtype=torch.int64, device='cuda')

for dropout in [0.25, 0.5]:
  print('Running check with dropout = ', dropout)
  model = FullyConnectedNet([H1, H2], input_dim=D, num_classes=C,
                            weight_scale=5e-2, dropout=dropout,
                            seed=0, dtype=torch.float64, device='cuda')

  loss, grads = model.loss(X, y)
  print('Initial loss: ', loss.item())
  
  # Relative errors should be around e-5 or less.
  for name in sorted(grads):
    f = lambda _: model.loss(X, y)[0]
    grad_num = eecs598.grad.compute_numeric_gradient(f, model.params[name])
    print('%s relative error: %.2e' % (name, eecs598.grad.rel_error(grad_num, grads[name])))
  print()
# Out:
# Running check with dropout =  0.25
# Initial loss:  2.2983730764546393
# W1 relative error: 3.43e-08
# W2 relative error: 6.76e-08
# W3 relative error: 5.00e-08
# b1 relative error: 6.78e-08
# b2 relative error: 1.50e-08
# b3 relative error: 2.39e-09
#
# Running check with dropout =  0.5
# Initial loss:  2.322923576060469
# W1 relative error: 1.50e-08
# W2 relative error: 1.52e-08
# W3 relative error: 1.53e-08
# b1 relative error: 3.05e-08
# b2 relative error: 7.06e-09
# b3 relative error: 3.68e-09

# %% [markdown]
# ## Regularization experiment
# To get a sense of the way that dropout can regularize a neural network, we will train three different two-layer networks:
#
# 1. Hidden size 256, dropout = 0
# 2. Hidden size 512, dropout = 0
# 3. Hidden size 512, dropout = 0.5
#
# We will then visualize the training and validation accuracies of these three networks.

# %%
from fully_connected_networks import FullyConnectedNet

# Train two identical nets, one with dropout and one without
reset_seed(0)
num_train = 20000
small_data = {
  'X_train': data_dict['X_train'][:num_train],
  'y_train': data_dict['y_train'][:num_train],
  'X_val': data_dict['X_val'],
  'y_val': data_dict['y_val'],
}

solvers = {}
dropout_choices = [0, 0, 0.5]
width_choices = [256, 512, 512]
for dropout, width in zip(dropout_choices, width_choices):
# for dropout in dropout_choices:
  model = FullyConnectedNet([width], dropout=dropout, dtype=torch.float32, device='cuda')
  print('Training a model with dropout=%.2f and width=%d' % (dropout, width))

  solver = Solver(model, small_data,
                  num_epochs=100, batch_size=512,
                  update_rule=adam,
                  optim_config={
                    'learning_rate': 5e-3,
                  },
                  print_every=100000, print_acc_every=10,
                  verbose=True, device='cuda')
  solver.train()
  solvers[(dropout, width)] = solver
  print()
# Out:
# Training a model with dropout=0.00 and width=256
# (Time 0.03 sec; Iteration 1 / 3900) loss: 2.302505
# (Epoch 0 / 100) train acc: 0.213000; val_acc: 0.212100
# (Epoch 10 / 100) train acc: 0.707000; val_acc: 0.474600
# (Epoch 20 / 100) train acc: 0.849000; val_acc: 0.480000
# (Epoch 30 / 100) train acc: 0.898000; val_acc: 0.453200
# (Epoch 40 / 100) train acc: 0.960000; val_acc: 0.467400
# (Epoch 50 / 100) train acc: 0.961000; val_acc: 0.461200
# (Epoch 60 / 100) train acc: 0.989000; val_acc: 0.468800
# (Epoch 70 / 100) train acc: 0.978000; val_acc: 0.466000
# (Epoch 80 / 100) train acc: 0.980000; val_acc: 0.462900
# (Epoch 90 / 100) train acc: 0.945000; val_acc: 0.460600
# (Epoch 100 / 100) train acc: 0.983000; val_acc: 0.459200
#
# Training a model with dropout=0.00 and width=512
# (Time 0.02 sec; Iteration 1 / 3900) loss: 2.301456
# (Epoch 0 / 100) train acc: 0.185000; val_acc: 0.206800
# (Epoch 10 / 100) train acc: 0.722000; val_acc: 0.473000
# (Epoch 20 / 100) train acc: 0.864000; val_acc: 0.466100
# (Epoch 30 / 100) train acc: 0.917000; val_acc: 0.478700
# (Epoch 40 / 100) train acc: 0.931000; val_acc: 0.455900
# (Epoch 50 / 100) train acc: 0.955000; val_acc: 0.472100
# (Epoch 60 / 100) train acc: 0.949000; val_acc: 0.461700
# (Epoch 70 / 100) train acc: 0.963000; val_acc: 0.469200
# (Epoch 80 / 100) train acc: 0.971000; val_acc: 0.472100
# (Epoch 90 / 100) train acc: 0.973000; val_acc: 0.465700
# (Epoch 100 / 100) train acc: 1.000000; val_acc: 0.484300
#
# Training a model with dropout=0.50 and width=512
# (Time 0.01 sec; Iteration 1 / 3900) loss: 2.302781
# (Epoch 0 / 100) train acc: 0.231000; val_acc: 0.239600
# (Epoch 10 / 100) train acc: 0.625000; val_acc: 0.472200
# (Epoch 20 / 100) train acc: 0.657000; val_acc: 0.473300
# (Epoch 30 / 100) train acc: 0.762000; val_acc: 0.496400
# (Epoch 40 / 100) train acc: 0.824000; val_acc: 0.497800
# (Epoch 50 / 100) train acc: 0.834000; val_acc: 0.494800
# (Epoch 60 / 100) train acc: 0.878000; val_acc: 0.493600
# (Epoch 70 / 100) train acc: 0.874000; val_acc: 0.500600
# (Epoch 80 / 100) train acc: 0.918000; val_acc: 0.498600
# (Epoch 90 / 100) train acc: 0.923000; val_acc: 0.502800
# (Epoch 100 / 100) train acc: 0.939000; val_acc: 0.487000

# %% [markdown]
# If everything worked as expected, you should see that the network with dropout has lower training accuracies than the networks without dropout, but that it achieves higher validation accuracies.
#
# You should also see that a network with width 512 and dropout 0.5 achieves higher validation accuracies than a network with width 256 and no dropout. This demonstrates that reducing the model size is not generally an effective regularization strategy -- it's often better to use a larger model with explicit regularization.

# %%
plt.subplot(2, 1, 1)
for (dropout, width), solver in solvers.items():
  train_acc = solver.train_acc_history
  label = 'dropout=%.2f, width=%d' % (dropout, width)
  plt.plot(train_acc, 'o', label=label)
plt.title('Train accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(ncol=2, loc='lower right')
  
plt.subplot(2, 1, 2)
for (dropout, width), solver in solvers.items():
  val_acc = solver.val_acc_history
  label = 'dropout=%.2f, width=%d' % (dropout, width)
  plt.plot(val_acc, 'o', label=label)
plt.ylim(0.4, 0.52)
plt.title('Val accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(ncol=2, loc='lower right')

plt.gcf().set_size_inches(10, 15)
plt.show()
